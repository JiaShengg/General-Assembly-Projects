# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# #### Problem Statement:
# As advisers to the US Department of Education, we are tasked to analyze the relative influences of socioeconomic status on SAT and ACT scores in each state and make recommendations for appropriate funding measures to ensure that all states have equal educational chances. We will approach this analysis by identifying yearly trends of SAT/ ACT participation and scores from 2017 to 2019, and later study the effects of how US socioeconomic status impacts the performance in these national exams.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math. The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section.

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*
#
# ### Additional Background Info
#
# Aside from being a standardized college entrance exam, SAT and ACT scores are also used to compare schools and states on the basis of their national average exam score and to evaluate state educational programs. A variety of factors can influence how well high school students perform in these national exams.
#
# Academic and institutional factors influence national exam scores at the state level. High schools with high historical SAT and ACT average scores tend to have lower teacher-to-students ratio, and thus, students benefit from receiving targeted attention which results in better exam scores. The rigorous curriculum and high-achieving educational environment appear to benefit the students since they are able to fully develop their potential, abilities, and strategies for taking the national exams ([*source0*](https://education.seattlepi.com/factors-influencing-sat-scores-2589.html)).
#
# At the individual level, socioeconomic status may also play a significant role in determining how well a student performs in these national exams. Low-income students may struggle not only to maintain consistent attendance in school where they can continuously learn, but they may also lack adequate materials to help them prepare for the exam ([*source0*](https://education.seattlepi.com/factors-influencing-sat-scores-2589.html)). Because their parents may not have attended college themselves, these students are also less likely to receive encouragement, motivation, and support to perform well in these exams.
#
# In this study, we will study the yearly trends of SAT and ACT national exams for a period of 3 years from 2017 to 2019, and identify states that have performed consistently poorly. Next, we will analyze the relative influences of socioeconomic status on SAT and ACT results in each state and make recommendations for appropriate funding measures to ensure that all states have equal educational chances.
#
#
# ### Methodology
# Following Blitzstein & Pfister’s workflow ([*source9*](https://github.com/cs109/2015/blob/master/Lectures/01-Introduction.pdf)), a 5 Steps framework was implemented to conduct this analysis. These 5 steps are:
#
# 1) Ask an interesting question
# - Defining a clear and concise problem statement.
#
# 2) Get the data
# - Import and clean raw data to ensure that all datatypes were accurate and any other errors were fixed.
#
# 3) Explore the data
# - Perform exploratory data analysis to determine any meaningful correlation between parameters to address problem statement.
#
# 4) Model the data
# - heat map
# - subplots
# - histograms
# - scatterplots
# - boxplots
# - interactive maps
#
# 5) Communicate and visualize the results
# - Present findings to a non-technical audience and provide recommendations

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`AvgPoverty(2018-2019).xlsx`](./data/AvgPoverty(2018-2019).xlsx): Poverty rate by State in the year 2018-2019
# * [`ACGR(2018-2019).xls`](./data/ACGR(2018-2019).xls): Public high school Adjusted Cohort Graduation rate (ACGR) of selected student characteristics (Economically disadvantaged, Homeless and Disabled) by State in the year 2018-2019

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# As part of this study, we will also look into the following datasets that provide us the data for US socioeconomic factors in each state:
#
# - 2-year average Poverty (2018-2019) from US Census Bureau ([*dataset1*](https://www.census.gov/data/tables/2020/demo/income-poverty/p60-270.html))
#
#
# - Adjusted Cohort Graduation Rate of high school of selected student characteristics (2018-2019) ([*dataset2*](https://nces.ed.gov/programs/digest/d18/tables/dt18_219.46.asp))
#
# - Other external sources cited in 'Recommendation and Conclusion' section to support funding recommendations.

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def calculate_mean(ls):
    
    return sum(i for i in ls)/len(ls)

# %%
calculate_mean([1,2,3,4])
# Out:
# 2.5

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def calculate_sd(ls):
    
    summation = sum((i-calculate_mean(ls))**2 for i in ls)
    return (summation*1/len(ls))**(0.5)

# %%
calculate_sd([1,2,3,4])
# Out:
# 1.118033988749895

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def convert_percentage(string):
    try:
        return float(string.strip('%'))/100
    except:
        return float(string)/100

# %%
convert_percentage('50.5%')
# Out:
# 0.505

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# ### 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook -> 2017 Data Import & Cleaning

# %%
act_2017 = pd.read_csv('../data/act_2017.csv')
sat_2017 = pd.read_csv('../data/sat_2017.csv')

# %%
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %% [markdown]
# ### 2. Check for missing values

# %%
act_2017.shape
# Out:
# (52, 7)

# %%
act_2017.isnull().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %%
sat_2017.shape
# Out:
# (51, 5)

# %%
sat_2017.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %% [markdown]
# #### OBSERVATIONS FROM DATAFRAMES
# No missing data for both SAT_2017 and ACT_2017 data frames. <br />
#
# Some other observations of the 2 dataframe: <br />
#
# ####   ACT_2017
# - ACT data frame consists of 'Participation' rate and average subject (English, Mathematics, Reading, Science) test scores for each state. <br />
# - 'Composite' score is calculated based on the average of 4 test scores for English, Mathematics, Reading and Science. <br />
# - The Composite score for the ACT exam and each test score (English, Mathematics, Reading, Science) range from 1 (low) to 36 (high). <br />
# - Contains 52 US states, additional of 1 US state.
#
# ####  SAT_2017
# - SAT data frame consists of 'Participation' rate, and shows the average scores for Evidence-Based Reading and Writing and Math' of each state. <br />
# - The 'Total' score is calculated based on the summation of the 2 sections (Evidence-Based Reading and Writing &
# Math). <br />
# - SAT is scored on a scale of 200 (low)-800 (high) for each section. <br />
# - 51 US states listed.

# %% [markdown]
# ### 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).

# %%
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# ### Convert columns object to float for act_2017 dataframe

# %%
#Changing  Participation rate to float type
act_2017['Participation']= act_2017['Participation'].apply(lambda x: convert_percentage(x))

# %%
#Check for strings in 'Composite' column
for variable in act_2017['Composite']:
    ls = []
    try:
        int(variable)
    except:
        ls.append(variable)

ls
# Out:
# ['20.2x']

# %%
#Checking the specific row that contains '20.2x'
act_2017.loc[act_2017['Composite']=="20.2x"]
# Out:
#       State  Participation  English  Math  Reading  Science Composite
# 51  Wyoming            1.0     19.4  19.8     20.8     20.6     20.2x

# %%
#Calculate composite score based on average score of the 4 subjects for Wyoming state
Wyoming_composite = round(act_2017.iloc[51:52,2:6].mean(axis=1),1).values
act_2017.loc[act_2017['Composite']=="20.2x",'Composite']=Wyoming_composite

# %%
act_2017['Composite']= act_2017['Composite'].apply(lambda x: float(x))

# %%
act_2017_summary = act_2017.describe()

# %%
act_2017_summary['Calculated Composite'] = act_2017_summary.iloc[:,2:6].mean(axis=1).values

# %%
act_2017_summary
# Out:
#        Participation    English       Math    Reading    Science  Composite  \
# count      52.000000  52.000000  52.000000  52.000000  52.000000  52.000000
# mean        0.651538  20.919231  21.173077  22.001923  21.040385  21.509615
# std         0.318325   2.332132   1.963602   2.048672   3.151113   2.002083
# min         0.080000  16.300000  18.000000  18.100000   2.300000  17.800000
# 25%         0.310000  19.000000  19.400000  20.475000  19.900000  19.800000
# 50%         0.680000  20.550000  20.900000  21.700000  21.150000  21.400000
# 75%         1.000000  23.300000  23.100000  24.125000  22.525000  23.600000
# max         1.000000  25.500000  25.300000  26.000000  24.900000  25.500000
#
#        Calculated Composite
# count             52.000000
# mean              21.431250
# std                2.291367
# min               14.050000
# 25%               19.893750
# 50%               21.287500
# 75%               23.337500
# max               25.425000

# %% [markdown]
# #### Observation:
# From the act_2017 data frame above, the min value composite score deviates from the calculated composite score (>20%), and will require further investigation

# %%
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %% [markdown]
# ### Convert columns object to float for sat_2017 dataframe

# %%
sat_2017['Participation']= sat_2017['Participation'].apply(lambda x: convert_percentage(x))

# %%
sat_2017_summary = sat_2017.describe()

# %%
sat_2017_summary['Calculated_total']= sat_2017_summary.iloc[:,1:3].sum(axis=1).values

# %%
sat_2017_summary.iloc[1:,:]
# Out:
#       Participation  Evidence-Based Reading and Writing        Math  \
# mean       0.398039                          569.117647  547.627451
# std        0.352766                           45.666901   84.909119
# min        0.020000                          482.000000   52.000000
# 25%        0.040000                          533.500000  522.000000
# 50%        0.380000                          559.000000  548.000000
# 75%        0.660000                          613.000000  599.000000
# max        1.000000                          644.000000  651.000000
#
#             Total  Calculated_total
# mean  1126.098039       1116.745098
# std     92.494812        130.576020
# min    950.000000        534.000000
# 25%   1055.500000       1055.500000
# 50%   1107.000000       1107.000000
# 75%   1212.000000       1212.000000
# max   1295.000000       1295.000000

# %% [markdown]
# #### Observation:
# From the sat_2017 data frame above, min values total score deviates from the calculated total score (>40%). A slight deviation of Total VS Calculated mean is also observed. Will require further investigation

# %% [markdown]
# ### 4. Fix any errors you identified in steps 2-3.

# %% [markdown]
# ### SAT_2017 DATAFRAME

# %% [markdown]
# #### Since we know min score for SAT of each subject is 200, and the maximum score is 800, we are able to filter out rows beyond these limits

# %%
sat_2017[(sat_2017['Math']<200) | (sat_2017['Math']>800) | (sat_2017['Evidence-Based Reading and Writing']<200) | (sat_2017['Evidence-Based Reading and Writing']>800)]
# Out:
#        State  Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           0.69                                 536    52   1060

# %% [markdown]
# #### Error was found in Maryland state, the likely 'Math' score should have been 524 not 52

# %%
sat_2017.loc[sat_2017['State']=='Maryland','Math'] = 524

# %%
sat_2017_summary = sat_2017.describe()

# %%
sat_2017_summary['Calculated_total']= sat_2017_summary.iloc[:,1:3].sum(axis=1).values
sat_2017_summary.iloc[1:,:]
# Out:
#       Participation  Evidence-Based Reading and Writing        Math  \
# mean       0.398039                          569.117647  556.882353
# std        0.352766                           45.666901   47.121395
# min        0.020000                          482.000000  468.000000
# 25%        0.040000                          533.500000  523.500000
# 50%        0.380000                          559.000000  548.000000
# 75%        0.660000                          613.000000  599.000000
# max        1.000000                          644.000000  651.000000
#
#             Total  Calculated_total
# mean  1126.098039       1126.000000
# std     92.494812         92.788297
# min    950.000000        950.000000
# 25%   1055.500000       1057.000000
# 50%   1107.000000       1107.000000
# 75%   1212.000000       1212.000000
# max   1295.000000       1295.000000

# %% [markdown]
# #### The mean and minimum values corrected for sat_2017 data frame

# %% [markdown]
# ### ACT_2017 DATAFRAME

# %% [markdown]
# #### Since we know min score for ACT of each subject is 1, and the maximum score is 36, we are able to filter out rows that are beyond these limits

# %%
subjects = ['English','Math','Reading','Science']

for subject in subjects:
       
    df = act_2017[(act_2017[subject]<1) | (act_2017[subject]>36)]
    if df.empty:
        print(subject)
        print('Test score are within acceptable limits \n')
    else:
        print(subject)
        print(df)
# Out:
# English
# Test score are within acceptable limits
#
# Math
# Test score are within acceptable limits
#
# Reading
# Test score are within acceptable limits
#
# Science
# Test score are within acceptable limits

# %% [markdown]
# ### Comparing calculated composite score VS raw composite score for discrepancies

# %%
act_2017['Calculated Composite'] = act_2017.iloc[:,2:6].mean(axis=1).values

# %%
upper_limit = 0.01
lower_limit = -0.01
act_2017[((act_2017['Composite']-act_2017['Calculated Composite'])/act_2017['Composite'] > upper_limit) | ((act_2017['Composite']-act_2017['Calculated Composite'])/act_2017['Composite'] < lower_limit)]
# Out:
#        State  Participation  English  Math  Reading  Science  Composite  \
# 21  Maryland           0.28     23.3  23.1     24.2      2.3       23.6
#
#     Calculated Composite
# 21                18.225

# %% [markdown]
# Error was found in Maryland state (again), the likely 'Science' score should have been 23.8 not 2.3

# %%
act_2017.loc[act_2017['State']=='Maryland','Science']=23.8

# %%
act_2017 = act_2017.drop(columns='Calculated Composite')

# %%
act_2017.head()
# Out:
#       State  Participation  English  Math  Reading  Science  Composite
# 0  National           0.60     20.3  20.7     21.4     21.0       21.0
# 1   Alabama           1.00     18.9  18.4     19.7     19.4       19.2
# 2    Alaska           0.65     18.7  19.8     20.4     19.9       19.8
# 3   Arizona           0.62     18.6  19.8     20.1     19.8       19.7
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5       19.4

# %%
act_2017_summary = act_2017.describe()

# %%
act_2017_summary['Calculated Composite'] = act_2017_summary.iloc[:,2:6].mean(axis=1).values

# %%
act_2017_summary
# Out:
#        Participation    English       Math    Reading    Science  Composite  \
# count      52.000000  52.000000  52.000000  52.000000  52.000000  52.000000
# mean        0.651538  20.919231  21.173077  22.001923  21.453846  21.509615
# std         0.318325   2.332132   1.963602   2.048672   1.737303   2.002083
# min         0.080000  16.300000  18.000000  18.100000  18.200000  17.800000
# 25%         0.310000  19.000000  19.400000  20.475000  19.975000  19.800000
# 50%         0.680000  20.550000  20.900000  21.700000  21.300000  21.400000
# 75%         1.000000  23.300000  23.100000  24.125000  23.200000  23.600000
# max         1.000000  25.500000  25.300000  26.000000  24.900000  25.500000
#
#        Calculated Composite
# count             52.000000
# mean              21.534615
# std                1.937915
# min               18.025000
# 25%               19.912500
# 50%               21.325000
# 75%               23.506250
# max               25.425000

# %% [markdown]
# #### Observation:
# The minimum value corrected for act_2017 data frame with less than <1% error between actual VS calculated composite score

# %% [markdown]
# ### 5. Display the data types of each feature.

# %% [markdown]
# #### Converted to Float/Int in part 1

# %%
act_2017.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
sat_2017.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %% [markdown]
# ### 6. Fix any incorrect data types found in step 5.
# Fix any individual values preventing other columns from being the appropriate type.
# If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! Hint: use .map() or .apply().

# %% [markdown]
# ### Resolved in Part 1 (Please see above)

# %% [markdown]
# ### 7. Rename Columns.
# Column names should be all lowercase.
# Column names should not contain spaces (underscores will suffice--this allows for using the df.column_name method to access columns in addition to df['column_name']).
# Column names should be unique and informative.

# %%
sat_2017.columns= sat_2017.columns.str.lower()
sat_2017.head()
# Out:
#         state  participation  evidence-based reading and writing  math  total
# 0     Alabama           0.05                                 593   572   1165
# 1      Alaska           0.38                                 547   533   1080
# 2     Arizona           0.30                                 563   553   1116
# 3    Arkansas           0.03                                 614   594   1208
# 4  California           0.53                                 531   524   1055

# %%
act_2017.columns= act_2017.columns.str.lower()
act_2017.head()
# Out:
#       state  participation  english  math  reading  science  composite
# 0  National           0.60     20.3  20.7     21.4     21.0       21.0
# 1   Alabama           1.00     18.9  18.4     19.7     19.4       19.2
# 2    Alaska           0.65     18.7  19.8     20.4     19.9       19.8
# 3   Arizona           0.62     18.6  19.8     20.1     19.8       19.7
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5       19.4

# %% [markdown]
# ### 8. Drop unnecessary rows (if needed).

# %% [markdown]
# ### Completed in above steps

# %% [markdown]
# ### 9. Merge dataframes that can be merged.

# %%
sat_2017 = sat_2017.rename(columns={"participation": "sat17_participation", "evidence-based reading and writing": "sat17_ebrw", "math": "sat17_math", "total": "sat17_total"})
sat_2017.head(3)
# Out:
#      state  sat17_participation  sat17_ebrw  sat17_math  sat17_total
# 0  Alabama                 0.05         593         572         1165
# 1   Alaska                 0.38         547         533         1080
# 2  Arizona                 0.30         563         553         1116

# %%
act_2017 = act_2017.rename(columns={"participation": "act17_participation", "english": "act17_english", "math": "act17_math", "reading": "act17_reading", "science": "act17_science", "composite": "act17_composite"})
act_2017.head(3)
# Out:
#       state  act17_participation  act17_english  act17_math  act17_reading  \
# 0  National                 0.60           20.3        20.7           21.4
# 1   Alabama                 1.00           18.9        18.4           19.7
# 2    Alaska                 0.65           18.7        19.8           20.4
#
#    act17_science  act17_composite
# 0           21.0             21.0
# 1           19.4             19.2
# 2           19.9             19.8

# %% [markdown]
# ### Merge ACT_2017 dataframe to SAT_2017 based on 'state', remove additional state from ACT data frame

# %%
merged_2017 = sat_2017.merge(act_2017, how = 'left', on = ('state').lower())

# %%
#additional state from ACT data frame has been removed
merged_2017.shape
# Out:
# (51, 11)

# %%
merged_2017.head(5)
# Out:
#         state  sat17_participation  sat17_ebrw  sat17_math  sat17_total  \
# 0     Alabama                 0.05         593         572         1165
# 1      Alaska                 0.38         547         533         1080
# 2     Arizona                 0.30         563         553         1116
# 3    Arkansas                 0.03         614         594         1208
# 4  California                 0.53         531         524         1055
#
#    act17_participation  act17_english  act17_math  act17_reading  \
# 0                 1.00           18.9        18.4           19.7
# 1                 0.65           18.7        19.8           20.4
# 2                 0.62           18.6        19.8           20.1
# 3                 1.00           18.9        19.0           19.7
# 4                 0.31           22.5        22.7           23.1
#
#    act17_science  act17_composite
# 0           19.4             19.2
# 1           19.9             19.8
# 2           19.8             19.7
# ...

# %% [markdown]
# #### Observation:
# Finding the additional state observed in act_2017 dataframe

# %%
pd.concat([sat_2017['state'].str.lower(),act_2017['state'].str.lower()]).drop_duplicates(keep=False)
# Out:
# 0    national
# Name: state, dtype: object

# %% [markdown]
# ### 10. Perform any additional cleaning that you feel is necessary.

# %% [markdown]
# ### Import and clean 2018 dataframes

# %%
act_2018 = pd.read_csv('../data/act_2018.csv')
sat_2018 = pd.read_csv('../data/sat_2018.csv')

# %% [markdown]
# ### Check for missing data

# %%
print(act_2018.isnull().sum())
print(sat_2018.isnull().sum())
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %% [markdown]
# ### Check for any duplicate data

# %%
print(act_2018.shape)
print(sat_2018.shape)
# Out:
# (52, 3)
# (51, 5)

# %% [markdown]
# #### Observation:
# Drop duplicated row data, which is observed to be state = 'Maine' in act_2017 dataframe & reset index

# %%
act_2018.drop_duplicates(subset=['State'], inplace=True)
act_2018.reset_index(drop=True, inplace=True)
act_2018.shape
# Out:
# (51, 3)

# %% [markdown]
# ### Convert object to float for both dataframes

# %% [markdown]
# ### ACT_2018 DATAFRAME

# %%
act_2018.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
act_2018['Participation']= act_2018['Participation'].apply(lambda x: convert_percentage(x))

# %%
act_2018.dtypes
# Out:
# State             object
# Participation    float64
# Composite        float64
# dtype: object

# %% [markdown]
# ### SAT_2018 DATAFRAME

# %%
sat_2018.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
sat_2018['Participation']= sat_2018['Participation'].apply(lambda x: convert_percentage(x))

# %%
sat_2018.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
sat_2018.describe()
# Out:
#        Participation  Evidence-Based Reading and Writing        Math  \
# count      51.000000                           51.000000   51.000000
# mean        0.457451                          563.686275  556.235294
# std         0.373143                           47.502627   47.772623
# min         0.020000                          480.000000  480.000000
# 25%         0.045000                          534.500000  522.500000
# 50%         0.520000                          552.000000  544.000000
# 75%         0.775000                          610.500000  593.500000
# max         1.000000                          643.000000  655.000000
#
#              Total
# count    51.000000
# mean   1120.019608
# std      94.155083
# min     977.000000
# 25%    1057.500000
# 50%    1098.000000
# 75%    1204.000000
# max    1298.000000

# %% [markdown]
# #### Observation:
# From the sat_2018 data frame above, a slight deviation of Total VS Calculated min is observed. Will require further investigation

# %%
sat_2018[(sat_2018['Math']<200) | (sat_2018['Math']>800) | (sat_2018['Evidence-Based Reading and Writing']<200) | (sat_2018['Evidence-Based Reading and Writing']>800)]
# Out:
# Empty DataFrame
# Columns: [State, Participation, Evidence-Based Reading and Writing, Math, Total]
# Index: []

# %% [markdown]
# #### Observation:
# All test subjects are within acceptable limits (200 to 800)

# %%
sat_2018['Calculated Total'] = sat_2018.iloc[:,2:4].sum(axis=1).values

# %%
upper_limit = 0.01
lower_limit = -0.01

sat_2018[((sat_2018['Total']-sat_2018['Calculated Total'])/sat_2018['Total'] > upper_limit) | ((sat_2018['Total']-sat_2018['Calculated Total'])/sat_2018['Total'] < lower_limit)]
# Out:
# Empty DataFrame
# Columns: [State, Participation, Evidence-Based Reading and Writing, Math, Total, Calculated Total]
# Index: []

# %% [markdown]
# #### Observation:
# Actual total score is less than ±1% from calculated total score. Hence, sat_2018 data frame is deemed to be accurate.

# %% [markdown]
# ### Rename Columns and Merge both 2018 dataframes based on 'state'

# %%
sat_2018 = sat_2018.rename(columns={"State":"state","Participation": "sat18_participation", "Evidence-Based Reading and Writing": "sat18_ebrw", "Math": "sat18_math", "Total": "sat18_total"})
sat_2018.drop(columns='Calculated Total', inplace=True)
sat_2018.head()
# Out:
#         state  sat18_participation  sat18_ebrw  sat18_math  sat18_total
# 0     Alabama                 0.06         595         571         1166
# 1      Alaska                 0.43         562         544         1106
# 2     Arizona                 0.29         577         572         1149
# 3    Arkansas                 0.05         592         576         1169
# 4  California                 0.60         540         536         1076

# %%
act_2018 = act_2018.rename(columns={"State":"state", "Participation": "act18_participation", "Composite": "act18_composite"})
act_2018.head(3)
# Out:
#      state  act18_participation  act18_composite
# 0  Alabama                 1.00             19.1
# 1   Alaska                 0.33             20.8
# 2  Arizona                 0.66             19.2

# %%
merged_2018 = sat_2018.merge(act_2018, how = 'left', on = ('state').lower())

# %%
merged_2018.shape
# Out:
# (51, 7)

# %%
merged_2018.head()
# Out:
#         state  sat18_participation  sat18_ebrw  sat18_math  sat18_total  \
# 0     Alabama                 0.06         595         571         1166
# 1      Alaska                 0.43         562         544         1106
# 2     Arizona                 0.29         577         572         1149
# 3    Arkansas                 0.05         592         576         1169
# 4  California                 0.60         540         536         1076
#
#    act18_participation  act18_composite
# 0                 1.00             19.1
# 1                 0.33             20.8
# 2                 0.66             19.2
# 3                 1.00             19.4
# 4                 0.27             22.7

# %% [markdown]
# ### Import and clean 2019 Dataframes

# %%
act_2019 = pd.read_csv('../data/act_2019.csv')
sat_2019 = pd.read_csv('../data/sat_2019.csv')

# %% [markdown]
# ### Check for missing data

# %%
print(act_2019.isnull().sum())
print(sat_2019.isnull().sum())
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %% [markdown]
# ### Check for any duplicate data

# %%
print(act_2019.shape)
print(sat_2019.shape)
# Out:
# (52, 3)
# (53, 5)

# %%
print(act_2019['State'].nunique())
print(sat_2019['State'].nunique())
# Out:
# 52
# 53

# %% [markdown]
# ### No duplicate data found in dataframes, therefore invalid states must have been added

# %%
states = merged_2018['state']
state_ls = []
for state in states:
    state_ls.append(state)

len(state_ls)
# Out:
# 51

# %%
act_2019= act_2019[act_2019['State'].isin(state_ls)]
sat_2019= sat_2019[sat_2019['State'].isin(state_ls)]

# %%
print(act_2019.shape)
print(sat_2019.shape)
# Out:
# (51, 3)
# (51, 5)

# %% [markdown]
# ### Convert object to float for both data frames

# %% [markdown]
# ### ACT_2019 DATAFRAME

# %%
act_2019.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
act_2019['Participation']= act_2019['Participation'].apply(lambda x: convert_percentage(x))

# %%
act_2019.dtypes
# Out:
# State             object
# Participation    float64
# Composite        float64
# dtype: object

# %% [markdown]
# ### SAT_2019 DATAFRAME

# %%
sat_2019.dtypes
# Out:
# State                 object
# Participation Rate    object
# EBRW                   int64
# Math                   int64
# Total                  int64
# dtype: object

# %%
sat_2019['Participation Rate']= sat_2019['Participation Rate'].apply(lambda x: convert_percentage(x));

# %%
sat_2019.dtypes
# Out:
# State                  object
# Participation Rate    float64
# EBRW                    int64
# Math                    int64
# Total                   int64
# dtype: object

# %%
sat_2019_summary=sat_2019.describe()

# %%
sat_2019_summary['Calculated_total']= sat_2019_summary.iloc[:,1:3].sum(axis=1).values
sat_2019_summary.iloc[1:,:]
# Out:
#       Participation Rate        EBRW        Math        Total  \
# mean            0.490588  560.803922  552.196078  1113.078431
# std             0.387476   46.248035   51.290553    97.197910
# min             0.020000  483.000000  460.000000   943.000000
# 25%             0.055000  527.500000  511.500000  1038.000000
# 50%             0.540000  550.000000  546.000000  1097.000000
# 75%             0.820000  612.000000  599.000000  1210.000000
# max             1.000000  636.000000  648.000000  1284.000000
#
#       Calculated_total
# mean       1113.000000
# std          97.538588
# min         943.000000
# 25%        1039.000000
# 50%        1096.000000
# 75%        1211.000000
# max        1284.000000

# %% [markdown]
# #### Observation:
# Calculated total score looks consistent with actual data.

# %% [markdown]
# ### Rename Columns and Merge both 2019 dataframes based on 'state'

# %%
sat_2019 = sat_2019.rename(columns={"State":"state","Participation Rate": "sat19_participation", "EBRW": "sat19_ebrw", "Math": "sat19_math", "Total": "sat19_total"})
sat_2019.head(3)
# Out:
#      state  sat19_participation  sat19_ebrw  sat19_math  sat19_total
# 0  Alabama                 0.07         583         560         1143
# 1   Alaska                 0.41         556         541         1097
# 2  Arizona                 0.31         569         565         1134

# %%
act_2019 = act_2019.rename(columns={"State":"state", "Participation": "act19_participation", "Composite": "act19_composite"})
act_2019.head(3)
# Out:
#      state  act19_participation  act19_composite
# 0  Alabama                 1.00             18.9
# 1   Alaska                 0.38             20.1
# 2  Arizona                 0.73             19.0

# %%
merged_2019 = sat_2019.merge(act_2019, how = 'left', on = ('state').lower())

# %%
print(merged_2017.shape)
print(merged_2018.shape)
print(merged_2019.shape)
# Out:
# (51, 11)
# (51, 7)
# (51, 7)

# %% [markdown]
# ### 11. Save your cleaned and merged dataframes as csv files.

# %%
merged_2017.to_csv('../data/merged_2017.csv', index=False)
merged_2018.to_csv('../data/merged_2018.csv', index=False)
merged_2019.to_csv('../data/merged_2019.csv', index=False)

# %% [markdown]
# ### 12. Import Extenal Datasets for analysis
#
# * [`AvgPoverty(2018-2019).xls`]: Avg No. of People under Poverty by State in the year 2018-2019
# * [`ACGR(2018-2019).xls`]: Public high school Adjusted Cohort Graduation rate (ACGR), by selected student characteristics (Economically disadvantaged, homeless and disabilities) by State in the year 2018-2019

# %% [markdown]
# ### AvgPoverty(2018-2019) Data Cleaning

# %%
avg_poverty_df = pd.read_excel('../data/AvgPoverty(2018-2019).xlsx', header=[4])
avg_poverty_df.head(10)
# Out:
#            Unnamed: 0 3-year average              Unnamed: 2  Unnamed: 3  \
# 0                 NaN      2017-2019                     NaN  2016-20171
# 1                 NaN     Percentage  Margin of error2 (+/-)  Percentage
# 2                 NaN            NaN                     NaN         NaN
# 3                 NaN            NaN                     NaN         NaN
# 4       United States           11.5                     0.2        12.5
# 5             Alabama           14.7                     1.7        16.1
# 6              Alaska           11.8                       1        11.8
# 7             Arizona           12.1                     1.7        15.2
# 8            Arkansas             15                     1.3        15.3
# 9          California           11.4                     0.5        12.8
#
#                Unnamed: 4  Unnamed: 5              Unnamed: 6  Unnamed: 7  \
# 0                     NaN   2018-2019                     NaN         NaN
# ...

# %%
avg_poverty_df.tail(10)
# Out:
#                                            Unnamed: 0 3-year average  \
# 51                                           Virginia            9.7
# 52                                         Washington            8.8
# 53                                      West Virginia           15.6
# 54                                          Wisconsin            8.7
# 55                                            Wyoming           10.5
# 56  *An asterisk preceding an estimate indicates c...            NaN
# 57  1 To calculate this 2-year average, we used th...            NaN
# 58  2 A margin of error (MOE) is a measure of an e...            NaN
# 59  Note: Details may not sum to totals because of...            NaN
# 60  Source: U.S. Census Bureau, Current Population...            NaN
#
#    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 51        1.1       11.1        1.1        9.3        1.4       -1.8
# ...

# %% [markdown]
# #### Reformat dataset to reflect State 'Alabama' as first row and dataset to end with state 'Wyoming'. The data frame should also be filtered to only show the average poverty rate for the years 2018-2019

# %%
avg_poverty_df = avg_poverty_df.iloc[5:56,:]
avg_poverty_df = avg_poverty_df[['Unnamed: 0','Unnamed: 5']]

# %%
avg_poverty_df.head()
# Out:
#    Unnamed: 0 Unnamed: 5
# 5     Alabama       14.4
# 6      Alaska       11.7
# 7     Arizona       11.4
# 8    Arkansas         15
# 9  California         11

# %% [markdown]
# #### Rename columns and reset index

# %%
avg_poverty_df = avg_poverty_df.rename(columns={"Unnamed: 0": "state","Unnamed: 5": "2_years_avg_proverty_rate"}).reset_index(drop=True)
avg_poverty_df.head()
# Out:
#         state 2_years_avg_proverty_rate
# 0     Alabama                      14.4
# 1      Alaska                      11.7
# 2     Arizona                      11.4
# 3    Arkansas                        15
# 4  California                        11

# %%
# check to ensure number of rows (states) is consistent with SAT/ACT dataframes (51 states)
avg_poverty_df.shape
# Out:
# (51, 2)

# %%
#check for missing data
avg_poverty_df.isnull().sum()
# Out:
# state                        0
# 2_years_avg_proverty_rate    0
# dtype: int64

# %%
avg_poverty_df.dtypes
# Out:
# state                        object
# 2_years_avg_proverty_rate    object
# dtype: object

# %% [markdown]
# #### Convert '2_yrs_avg_proverty_rate'  column to float

# %%
avg_poverty_df['2_years_avg_proverty_rate']= avg_poverty_df['2_years_avg_proverty_rate'].apply(lambda x: float(x))

# %%
avg_poverty_df.dtypes
# Out:
# state                         object
# 2_years_avg_proverty_rate    float64
# dtype: object

# %%
avg_poverty_df.head()
# Out:
#         state  2_years_avg_proverty_rate
# 0     Alabama                       14.4
# 1      Alaska                       11.7
# 2     Arizona                       11.4
# 3    Arkansas                       15.0
# 4  California                       11.0

# %% [markdown]
# ### ACGR(2018-2019) Data Cleaning

# %%
ACGR_df = pd.read_excel('../data/ACGR(2018-2019).xls', header=[2]) 
ACGR_df.head(10)
# Out:
#           Unnamed: 0 2010-11 Unnamed: 2 2011-12 Unnamed: 4 2012-13 Unnamed: 6  \
# 0                NaN     NaN        NaN     NaN        NaN     NaN        NaN
# 1                NaN     NaN        NaN     NaN        NaN     NaN        NaN
# 2                  1       2        NaN       3        NaN       4        NaN
# 3     United States       79        \6\      80        \6\    81.4        \7\
# 4        Alabama\9\       72        NaN      75        NaN      80        NaN
# 5            Alaska       68        NaN      70        NaN    71.8        NaN
# 6           Arizona       78        NaN      76        NaN    75.1        NaN
# 7          Arkansas       81        NaN      84        NaN    84.9        NaN
# 8        California       76        NaN      79        NaN    80.4        NaN
# 9          Colorado       74        NaN      75        NaN    76.9        NaN
#
#    2013- 14  2014- 15  2015- 16  ...       Unnamed: 18  \
# ...

# %%
ACGR_df.tail(15)
# Out:
#                                            Unnamed: 0 2010-11 Unnamed: 2  \
# 53                                         Wisconsin       87        NaN
# 54                                           Wyoming       80        NaN
# 55                                  ---Not available.     NaN        NaN
# 56                      ‡Reporting standards not met.     NaN        NaN
# 57  \1\The time when students are identified as ha...     NaN        NaN
# 58  \2\Students identified as children with disabi...     NaN        NaN
# 59  \3\Students who met the definition of limited ...     NaN        NaN
# 60  \4\Students who met the state criteria for cla...     NaN        NaN
# 61  \5\States either report data for a combined "A...     NaN        NaN
# 62  \6\Includes imputed data for Idaho, Kentucky, ...     NaN        NaN
# 63  \7\Includes imputed data for Idaho. Data were ...     NaN        NaN
# 64  \8\Estimated assuming a count of zero American...     NaN        NaN
# ...

# %% [markdown]
# #### Reformat dataset to reflect State 'Alabama' as first row and dataset to end with state Wyoming. Data frame should also be filtered to only show socioeconomic factors such as graduation rate of students with disabilities, economically disadvantaged, homeless for the years 2018-2019.

# %%
ACGR_df = ACGR_df.iloc[4:55,:]
ACGR_df.head()
# Out:
#     Unnamed: 0 2010-11 Unnamed: 2 2011-12 Unnamed: 4 2012-13 Unnamed: 6  \
# 4  Alabama\9\       72        NaN      75        NaN      80        NaN
# 5      Alaska       68        NaN      70        NaN    71.8        NaN
# 6     Arizona       78        NaN      76        NaN    75.1        NaN
# 7    Arkansas       81        NaN      84        NaN    84.9        NaN
# 8  California       76        NaN      79        NaN    80.4        NaN
#
#    2013- 14  2014- 15  2015- 16  ...  Unnamed: 18  Unnamed: 19  Unnamed: 20  \
# 4      86.3      89.3      87.1  ...           85           94          NaN
# 5      71.1      75.6      76.1  ...           80           68          NaN
# 6      75.7      77.4      79.5  ...           80         67.1          NaN
# 7      86.9      84.9      87.0  ...           76           79          NaN
# 8      81.0      82.0      83.0  ...           85           75          NaN
#
#   Unnamed: 21 Unnamed: 22 Students with disabil-ities  \
# ...

# %%
ACGR_df.tail()
# Out:
#         Unnamed: 0 2010-11 Unnamed: 2 2011-12 Unnamed: 4 2012-13 Unnamed: 6  \
# 50       Virginia       82        NaN      83        NaN    84.5        NaN
# 51     Washington       76        NaN      77        NaN    76.4        NaN
# 52  West Virginia       78        NaN      79        NaN    81.4        NaN
# 53      Wisconsin       87        NaN      88        NaN      88        NaN
# 54        Wyoming       80        NaN      79        NaN      77        NaN
#
#     2013- 14  2014- 15  2015- 16  ...  Unnamed: 18  Unnamed: 19  Unnamed: 20  \
# 50      85.3      85.7      86.7  ...           86           87          NaN
# 51      78.2      78.2      79.7  ...           75           62          NaN
# 52      84.5      86.5      89.8  ...         >=50           75          NaN
# 53      88.6      88.4      88.2  ...           83           79          NaN
# 54      78.6      79.3      80.0  ...         >=50           59          NaN
#
# ...

# %%
ACGR_df = ACGR_df[['Unnamed: 0','Students with disabil-ities', 'Economi- cally disadvan-taged', 'Homeless enrolled']]
ACGR_df.head()
# Out:
#     Unnamed: 0  Students with disabil-ities  Economi- cally disadvan-taged  \
# 4  Alabama\9\                          69.6                           87.4
# 5      Alaska                          60.0                           74.7
# 6     Arizona                          69.0                           73.5
# 7    Arkansas                          82.6                           84.8
# 8  California                          67.7                           81.1
#
#   Homeless enrolled
# 4                81
# 5                56
# 6                57
# 7                76
# 8                70

# %% [markdown]
# #### Rename columns and reset index

# %%
ACGR_df = ACGR_df.rename(columns={"Unnamed: 0": "state","Students with disabil-ities": "students_disabilities","Economi- cally disadvan-taged": "economically_disadvantaged"}).reset_index(drop=True)
ACGR_df.columns = ACGR_df.columns.str.lower()
ACGR_df.head()
# Out:
#          state  students_disabilities  economically_disadvantaged  \
# 0  Alabama\9\                    69.6                        87.4
# 1      Alaska                    60.0                        74.7
# 2     Arizona                    69.0                        73.5
# 3    Arkansas                    82.6                        84.8
# 4  California                    67.7                        81.1
#
#   homeless enrolled
# 0                81
# 1                56
# 2                57
# 3                76
# 4                70

# %% [markdown]
# #### Correcting the state names (i.e. Alabama\9\), checking for consistency of states with the previous data set (avg_poverty_df)

# %%
pd.concat([avg_poverty_df['state'].str.lower(),ACGR_df['state'].str.lower()]).drop_duplicates(keep=False)
# Out:
# 0            alabama
# 1             alaska
# 2            arizona
# 3           arkansas
# 4         california
#            ...
# 46         virginia
# 47       washington
# 48    west virginia
# 49        wisconsin
# 50          wyoming
# Name: state, Length: 98, dtype: object

# %% [markdown]
# #### Observation:
# Seems like all 'state' in ACGR data frame does not match with 'state' in avg_poverty_df, further investigation below:

# %%
avg_poverty_df['state'][1]
# Out:
# 'Alaska'

# %%
ACGR_df['state'][1]
# Out:
# 'Alaska '

# %% [markdown]
# #### Observation:
# Additional space in all 'state' for ACGR_df which prevents an identical match with 'state' in avg_poverty_df

# %%
# to strip white space in state
ACGR_df['state'] = ACGR_df['state'].str.strip()
ACGR_df['state'][1]
# Out:
# 'Alaska'

# %% [markdown]
# #### Check for consistency of 'state' spelling between ACGR_df and avg_poverty_df

# %%
# check to ensure number of rows (states) is consistent with avg_poverty_df (51 states)
ACGR_df.shape
# Out:
# (51, 4)

# %%
pd.concat([avg_poverty_df['state'].str.lower(),ACGR_df['state'].str.lower()]).drop_duplicates(keep=False)
# Out:
# 0       alabama
# 0    alabama\9\
# Name: state, dtype: object

# %% [markdown]
# #### Observation:
# All 'state' matches for the 2 dataframes except for alabama, corrected below:

# %%
ACGR_df['state'][0]='Alabama'
# Out:
# <ipython-input-114-6d6cfb1d35c1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ACGR_df['state'][0]='Alabama'

# %% [markdown]
# #### Check for 'state' spelling consistency again for the 2 dataframes

# %%
pd.concat([avg_poverty_df['state'].str.lower(),ACGR_df['state'].str.lower()]).drop_duplicates(keep=False)
# Out:
# Series([], Name: state, dtype: object)

# %% [markdown]
# #### Observation:
# Both data frames 'state' matches nicely now

# %% [markdown]
# #### Check for missing data

# %%
ACGR_df.isnull().sum()
# Out:
# state                         0
# students_disabilities         0
# economically_disadvantaged    0
# homeless enrolled             0
# dtype: int64

# %%
ACGR_df.dtypes
# Out:
# state                          object
# students_disabilities         float64
# economically_disadvantaged    float64
# homeless enrolled              object
# dtype: object

# %% [markdown]
# #### Convert 'homeless enrolled' and 'foster care ' columns to float

# %% [markdown]
# #### Observation:
# ACGR_df contains some objects that cannot be converted to float, therefore we have to replace them with NaN value. However, these symbols have meanings so it is worth noting them down. '‡' means Reporting standards not met.  '---' means data is not available.

# %%
ACGR_df.replace('‡', None, inplace=True)
ACGR_df.replace('---', None, inplace=True)
# Out:
# state                         None
# students_disabilities         None
# economically_disadvantaged    None
# homeless enrolled             None
# dtype: object

# %%
ACGR_df['homeless enrolled']= ACGR_df['homeless enrolled'].apply(lambda x: float(x))
ACGR_df.dtypes
# Out:
# state                          object
# students_disabilities         float64
# economically_disadvantaged    float64
# homeless enrolled             float64
# dtype: object

# %% [markdown]
# #### Since both  ACGR_df and avg_poverty_df look at data from 2018-2019, we will merge both data frame together for easier manipulation later

# %%
economical_summary_df = avg_poverty_df.merge(ACGR_df, how = 'left', on = ('state').lower())
economical_summary_df.shape
# Out:
# (51, 5)

# %%
economical_summary_df.head()
# Out:
#         state  2_years_avg_proverty_rate  students_disabilities  \
# 0     Alabama                       14.4                   69.6
# 1      Alaska                       11.7                   60.0
# 2     Arizona                       11.4                   69.0
# 3    Arkansas                       15.0                   82.6
# 4  California                       11.0                   67.7
#
#    economically_disadvantaged  homeless enrolled
# 0                        87.4               81.0
# 1                        74.7               56.0
# 2                        73.5               57.0
# 3                        84.8               76.0
# 4                        81.1               70.0

# %% [markdown]
# ### Save your cleaned and merged dataframe as csv files.

# %%
economical_summary_df.to_csv('../data/economic_summary(2018-2019).csv', index=False)

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|*string*| SAT / ACT | A state is a constituent political entity in America, of which there are currently 51 in this dataset.|
# |**sat_participation**|*float*| SAT_XX | Percentage of high school students who took the SAT Test in each State on Year XX |
# |**sat_ebrw**|*int*| SAT_XX | Mean score for SAT Evidence-Based Reading and Writing in Year XX in each State on Year XX |
# |**sat_math**|*int*| SAT_XX | Mean score for SAT Math in each State on Year XX |
# |**sat_total**|*int*| SAT_XX | Total score for SAT Test in each State on Year XX |
# |**act_participation**|*float*| ACT_XX | Percentage of high school students who took the ACT Test in each State on Year XX |
# |**act_english**|*float*| ACT_XX | Mean score for ACT English in each State on Year XX |
# |**act_math**|*float*| ACT_XX | Mean score for ACT Math in each State on Year XX |
# |**act_reading**|*float*| ACT_XX | Mean score for ACT Reading in each State on Year XX |
# |**act_science**|*float*| ACT_XX | Mean score for ACT Science in each State on Year XX |
# |**act_composite**|*float*| ACT_XX | Mean score for ACT Composite in each State on Year XX |
# |**2_years_avg_proverty_rate**|*float*| economical_summary(2018-2019) | Average poverty rate in each State for the Year 2018-2019 |
# |**students_disabilities**|*float*| economic_summary(2018-2019) | **ACGR for high school students with disabilities/1/ for the Year 2018-2019 |
# |**economically_disadvantaged**|*float*| economic_summary(2018-2019) | ACGR for high school students who are economically disadvantaged/2/ for the Year 2018-2019 |
# |**homeless_enrolled**|*float*| economic_summary(2018-2019) | ACGR for high school students who are homeless for the Year 2018-2019 |
#
#
# *ACGR - Adjusted cohort graduation rate for high school student
#
# /1/ Students identified as children with disabilities under the Individuals with Disabilities Education Act (IDEA).
#
# /2/ Students who met the state criteria for classification as economically disadvantaged.

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### 1a. Summary Statistic 2017

# %%
merged_2017.describe().T
# Out:
#                      count         mean        std     min      25%      50%  \
# sat17_participation   51.0     0.398039   0.352766    0.02     0.04     0.38
# sat17_ebrw            51.0   569.117647  45.666901  482.00   533.50   559.00
# sat17_math            51.0   556.882353  47.121395  468.00   523.50   548.00
# sat17_total           51.0  1126.098039  92.494812  950.00  1055.50  1107.00
# act17_participation   51.0     0.652549   0.321408    0.08     0.31     0.69
# act17_english         51.0    20.931373   2.353677   16.30    19.00    20.70
# act17_math            51.0    21.182353   1.981989   18.00    19.40    20.90
# act17_reading         51.0    22.013725   2.067271   18.10    20.45    21.80
# act17_science         51.0    21.462745   1.753392   18.20    19.95    21.30
# act17_composite       51.0    21.519608   2.020695   17.80    19.80    21.40
#
#                          75%     max
# sat17_participation     0.66     1.0
# sat17_ebrw            613.00   644.0
# ...

# %% [markdown]
# ### 1b. Summary Statistic 2018

# %%
merged_2018.describe().T
# Out:
#                      count         mean        std     min        25%  \
# sat18_participation   51.0     0.457451   0.373143    0.02     0.0450
# sat18_ebrw            51.0   563.686275  47.502627  480.00   534.5000
# sat18_math            51.0   556.235294  47.772623  480.00   522.5000
# sat18_total           51.0  1120.019608  94.155083  977.00  1057.5000
# act18_participation   50.0     0.623200   0.341141    0.07     0.2775
# act18_composite       50.0    21.454000   2.111312   17.70    19.9250
#
#                          50%       75%     max
# sat18_participation     0.52     0.775     1.0
# sat18_ebrw            552.00   610.500   643.0
# sat18_math            544.00   593.500   655.0
# sat18_total          1098.00  1204.000  1298.0
# act18_participation     0.66     1.000     1.0
# act18_composite        21.05    23.650    25.6

# %% [markdown]
# ### 1c. Summary Statistic 2019

# %%
merged_2019.describe().T
# Out:
#                      count         mean        std     min       25%      50%  \
# sat19_participation   51.0     0.490588   0.387476    0.02     0.055     0.54
# sat19_ebrw            51.0   560.803922  46.248035  483.00   527.500   550.00
# sat19_math            51.0   552.196078  51.290553  460.00   511.500   546.00
# sat19_total           51.0  1113.078431  97.197910  943.00  1038.000  1097.00
# act19_participation   51.0     0.586667   0.345159    0.06     0.245     0.54
# act19_composite       51.0    21.464706   2.194523   17.90    19.800    21.10
#
#                          75%     max
# sat19_participation     0.82     1.0
# sat19_ebrw            612.00   636.0
# sat19_math            599.00   648.0
# sat19_total          1210.00  1284.0
# act19_participation     1.00     1.0
# act19_composite        23.70    25.5

# %% [markdown]
# ### 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#      - Assign the output to variable `sd` as a dictionary where:
#      - Each column name is now a key
#      - That standard deviation of the column is the value
#      - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Merge all 2017,2018 and 2019 dataframes together
final_merged = merged_2017.merge(merged_2018,on='state').merge(merged_2019,on='state')

# %%
final_merged.head()
# Out:
#         state  sat17_participation  sat17_ebrw  sat17_math  sat17_total  \
# 0     Alabama                 0.05         593         572         1165
# 1      Alaska                 0.38         547         533         1080
# 2     Arizona                 0.30         563         553         1116
# 3    Arkansas                 0.03         614         594         1208
# 4  California                 0.53         531         524         1055
#
#    act17_participation  act17_english  act17_math  act17_reading  \
# 0                 1.00           18.9        18.4           19.7
# 1                 0.65           18.7        19.8           20.4
# 2                 0.62           18.6        19.8           20.1
# 3                 1.00           18.9        19.0           19.7
# 4                 0.31           22.5        22.7           23.1
#
#    act17_science  ...  sat18_math  sat18_total  act18_participation  \
# 0           19.4  ...         571         1166                 1.00
# ...

# %%
sd = {col:calculate_sd(final_merged[col]) for col in final_merged.columns if col != 'state'}
print(sd)
# Out:
# {'sat17_participation': 0.3492907076664507, 'sat17_ebrw': 45.21697020437866, 'sat17_math': 46.65713364485503, 'sat17_total': 91.58351056778743, 'act17_participation': 0.3182417575123181, 'act17_english': 2.3304876369363363, 'act17_math': 1.9624620273436781, 'act17_reading': 2.0469029314842646, 'act17_science': 1.7361170088327353, 'act17_composite': 2.000786081581989, 'sat18_participation': 0.3694661922353942, 'sat18_ebrw': 47.03460978357609, 'sat18_math': 47.30194550378352, 'sat18_total': 93.22742384464433, 'act18_participation': nan, 'act18_composite': nan, 'sat19_participation': 0.3836584048685726, 'sat19_ebrw': 45.792378682545134, 'sat19_math': 50.78521461840036, 'sat19_total': 96.24027185617864, 'act19_participation': 0.3417582373703047, 'act19_composite': 2.172901153595978}

# %%
final_merged.agg(['std']).T
# Out:
#                            std
# sat17_participation   0.352766
# sat17_ebrw           45.666901
# sat17_math           47.121395
# sat17_total          92.494812
# act17_participation   0.321408
# act17_english         2.353677
# act17_math            1.981989
# act17_reading         2.067271
# act17_science         1.753392
# act17_composite       2.020695
# sat18_participation   0.373143
# sat18_ebrw           47.502627
# sat18_math           47.772623
# sat18_total          94.155083
# act18_participation   0.341141
# act18_composite       2.111312
# sat19_participation   0.387476
# sat19_ebrw           46.248035
# sat19_math           51.290553
# sat19_total          97.197910
# act19_participation   0.345159
# act19_composite       2.194523

# %% [markdown]
# #### Observation:
# Manually calculated standard deviations differs slightly with the output from pandas 'describe'/'aggregate std' functions. On further investigation, we learn that pandas uses the unbiased estimator (N-1 in the denominator), whereas our manual formula does not.

# %% [markdown]
# #### Tweaking the original sd function formula to include biased estimator to check for consistency with pandas describe functions

# %%
def calculate_sd_biased_estimator(ls):
    
    summation = sum((i-calculate_mean(ls))**2 for i in ls)
    return (summation*1/(len(ls)-1))**(0.5)

# %%
sd1 = {col:calculate_sd_biased_estimator(final_merged[col]) for col in final_merged.columns if col != 'state'}
print(sd1)
# Out:
# {'sat17_participation': 0.35276632270013036, 'sat17_ebrw': 45.66690138768932, 'sat17_math': 47.12139516560329, 'sat17_total': 92.49481172519046, 'act17_participation': 0.32140842015886834, 'act17_english': 2.35367713980303, 'act17_math': 1.9819894936505533, 'act17_reading': 2.0672706264873146, 'act17_science': 1.7533922304280611, 'act17_composite': 2.020694891154341, 'sat18_participation': 0.37314256330391965, 'sat18_ebrw': 47.50262737831599, 'sat18_math': 47.77262322095955, 'sat18_total': 94.15508275097599, 'act18_participation': nan, 'act18_composite': nan, 'sat19_participation': 0.38747599546142664, 'sat19_ebrw': 46.24803546437109, 'sat19_math': 51.29055258343124, 'sat19_total': 97.1979100880785, 'act19_participation': 0.34515890060473114, 'act19_composite': 2.1945225931315235}

# %% [markdown]
# #### Observation:
# Manually calculated standard deviations match up with the output from pandas 'describe'/'aggregate std' functions after using the unbiased estimator (N-1 in the denominator) for our formula.

# %% [markdown]
# ### 3. Investigate trends in the data.
#
#     a. Which states have the highest and lowest participation rates for 2017, 2019, or 2019 SAT and ACT?
#     b. Do any states with 100% participation on a given test have a rate change year-to-year?
#     c. Do any states show have >50% participation on *both* tests each year?
#     d. Which state has the LOWEST COMBINED SAT & ACT Participation for the year of 2019?
#     e. Which states have the highest and lowest mean total/composite scores for 2017, 2019, or 2019 SAT and ACT?
#     f. Which state has the highest/lowest NORMALIZED SCORE from both SAT and ACT exams for the year of 2019?
#     g. From the additional dataset, which states have the highest/ lowest poverty rate/ economically disadvantaged high school students etc?

# %% [markdown]
# ### a) Which states have the highest and lowest participation rates for 2017, 2019, or 2019 SAT and ACT?

# %%
print(final_merged[['sat17_participation','sat18_participation','sat19_participation']].agg(['min','max']))
print(final_merged[['act17_participation','act18_participation','act19_participation']].agg(['min','max']))
# Out:
#      sat17_participation  sat18_participation  sat19_participation
# min                 0.02                 0.02                 0.02
# max                 1.00                 1.00                 1.00
#      act17_participation  act18_participation  act19_participation
# min                 0.08                 0.07                 0.06
# max                 1.00                 1.00                 1.00

# %% [markdown]
# #### Observation:
#
# **SAT Exam**
# - Min participation rate of 2% and Max participation rate of 100% for 2017-2019. To investigate which states have highest / lowest participation rate.
#
# **ACT Exam**
# - Min participation rate of 6-8% (decreasing trend) and Max participation rate of 100% for 2017-2019. To investigate which states have the highest/ lowest participation rate.

# %% [markdown]
# ### 2017 SAT Participation Analysis

# %%
min_mask = 0.02
max_mask = 1

sat_participation_17 = final_merged[['state','sat17_participation']]
sat_participation_17[(sat_participation_17['sat17_participation']==min_mask) | (sat_participation_17['sat17_participation']==max_mask)].sort_values('sat17_participation',ascending=False)
# Out:
#                    state  sat17_participation
# 6            Connecticut                 1.00
# 7               Delaware                 1.00
# 8   District of Columbia                 1.00
# 22              Michigan                 1.00
# 15                  Iowa                 0.02
# 24           Mississippi                 0.02
# 34          North Dakota                 0.02

# %% [markdown]
# ### 2017 ACT Participation Analysis

# %%
min_mask = 0.08
max_mask = 1

act_participation_17 = final_merged[['state','act17_participation']]
act_participation_17[(act_participation_17['act17_participation']==min_mask) | (act_participation_17['act17_participation']==max_mask)].sort_values('act17_participation',ascending=False)
# Out:
#              state  act17_participation
# 0          Alabama                 1.00
# 3         Arkansas                 1.00
# 49       Wisconsin                 1.00
# 44            Utah                 1.00
# 42       Tennessee                 1.00
# 40  South Carolina                 1.00
# 36        Oklahoma                 1.00
# 33  North Carolina                 1.00
# 28          Nevada                 1.00
# 26         Montana                 1.00
# 25        Missouri                 1.00
# 24     Mississippi                 1.00
# 23       Minnesota                 1.00
# 18       Louisiana                 1.00
# 17        Kentucky                 1.00
# 5         Colorado                 1.00
# 50         Wyoming                 1.00
# 19           Maine                 0.08

# %%
act_participation_17.sort_values('act17_participation', ascending=True).head()
# Out:
#             state  act17_participation
# 19          Maine                 0.08
# 29  New Hampshire                 0.18
# 7        Delaware                 0.18
# 39   Rhode Island                 0.21
# 38   Pennsylvania                 0.23

# %% [markdown]
# ### 2018 SAT Participation Analysis

# %%
min_mask = 0.02
max_mask = 1
sat_participation_18 = final_merged[['state','sat18_participation']]
sat_participation_18[(sat_participation_18['sat18_participation']==min_mask) | (sat_participation_18['sat18_participation']==max_mask)].sort_values('sat18_participation',ascending=False)
# Out:
#            state  sat18_participation
# 5       Colorado                 1.00
# 6    Connecticut                 1.00
# 7       Delaware                 1.00
# 12         Idaho                 1.00
# 22      Michigan                 1.00
# 34  North Dakota                 0.02

# %%
sat_participation_18.sort_values('sat18_participation',ascending=True).head()
# Out:
#            state  sat18_participation
# 34  North Dakota                 0.02
# 50       Wyoming                 0.03
# 41  South Dakota                 0.03
# 27      Nebraska                 0.03
# 49     Wisconsin                 0.03

# %% [markdown]
# ### 2018 ACT Participation Analysis

# %%
min_mask = 0.07
max_mask = 1

act_participation_18 = final_merged[['state','act18_participation']]
act_participation_18[(act_participation_18['act18_participation']==min_mask) | (act_participation_18['act18_participation']==max_mask)].sort_values('act18_participation',ascending=False)
# Out:
#              state  act18_participation
# 0          Alabama                 1.00
# 3         Arkansas                 1.00
# 49       Wisconsin                 1.00
# 44            Utah                 1.00
# 42       Tennessee                 1.00
# 40  South Carolina                 1.00
# 36        Oklahoma                 1.00
# 35            Ohio                 1.00
# 33  North Carolina                 1.00
# 28          Nevada                 1.00
# 27        Nebraska                 1.00
# 26         Montana                 1.00
# 25        Missouri                 1.00
# 24     Mississippi                 1.00
# 18       Louisiana                 1.00
# 17        Kentucky                 1.00
# 50         Wyoming                 1.00
# 19           Maine                 0.07

# %%
act_participation_18.sort_values('act18_participation',ascending=True).head(5)
# Out:
#             state  act18_participation
# 19          Maine                 0.07
# 39   Rhode Island                 0.15
# 29  New Hampshire                 0.16
# 7        Delaware                 0.17
# 38   Pennsylvania                 0.20

# %% [markdown]
# ### 2019 SAT Participation Analysis

# %%
min_mask = 0.02
max_mask = 1
sat_participation_19 = final_merged[['state','sat19_participation']]
sat_participation_19[(sat_participation_19['sat19_participation']==min_mask) | (sat_participation_19['sat19_participation']==max_mask)].sort_values('sat19_participation',ascending=False)
# Out:
#            state  sat19_participation
# 5       Colorado                 1.00
# 6    Connecticut                 1.00
# 7       Delaware                 1.00
# 9        Florida                 1.00
# 12         Idaho                 1.00
# 13      Illinois                 1.00
# 22      Michigan                 1.00
# 39  Rhode Island                 1.00
# 34  North Dakota                 0.02

# %%
sat_participation_19.sort_values('sat19_participation',ascending=True).head(5)
# Out:
#            state  sat19_participation
# 34  North Dakota                 0.02
# 50       Wyoming                 0.03
# 41  South Dakota                 0.03
# 27      Nebraska                 0.03
# 49     Wisconsin                 0.03

# %% [markdown]
# ### 2019 ACT Participation Analysis

# %%
min_mask = 0.06
max_mask = 1

act_participation_19 = final_merged[['state','act19_participation']]
act_participation_19[(act_participation_19['act19_participation']==min_mask) | (act_participation_19['act19_participation']==max_mask)].sort_values('act19_participation',ascending=False)
# Out:
#              state  act19_participation
# 0          Alabama                 1.00
# 3         Arkansas                 1.00
# 17        Kentucky                 1.00
# 18       Louisiana                 1.00
# 24     Mississippi                 1.00
# 26         Montana                 1.00
# 27        Nebraska                 1.00
# 28          Nevada                 1.00
# 33  North Carolina                 1.00
# 35            Ohio                 1.00
# 36        Oklahoma                 1.00
# 42       Tennessee                 1.00
# 44            Utah                 1.00
# 49       Wisconsin                 1.00
# 50         Wyoming                 1.00
# 19           Maine                 0.06

# %%
act_participation_19.sort_values('act19_participation',ascending=True).head(5)
# Out:
#             state  act19_participation
# 19          Maine                 0.06
# 39   Rhode Island                 0.12
# 7        Delaware                 0.13
# 29  New Hampshire                 0.14
# 38   Pennsylvania                 0.17

# %% [markdown]
# #### Observations:
#
# **SAT Highest Participation Rate**
#
# - 2017 SAT: District of Columbia, Michigan, Connecticut, Delaware, all with full participation
# - 2018 SAT: Colorado, Connecticut, Delaware, Michigan, Idaho, all with full participation
# - 2019 SAT: Colorado, Connecticut, Delaware, Florida, Idaho, Illinois, Michigan, Rhode Island, all with full participation
#
# - Michigan, Connecticut, and Delaware states have consistent full participation in SAT exam for all 3 years
#
# **ACT Highest Participation Rate**
#
# - 2017 ACT: 17 States (see list above), all with full participation
# - 2018 ACT: 17 States (see list above), all with full participation
# - 2016 ACT: 15 States (see list above), all with full participation
#
# - Michigan, Connecticut, and Delaware states have consistent full participation for all 3 years

# %% [markdown]
# #### Observations:
#
# **SAT Lowest Participation Rate**
#
# - 2017 SAT: North Dakota, Mississippi, Iowa with 2% participation rate
# - 2018 SAT: North Dakota with a 2% participation rate
# - 2019 SAT: North Dakota with a 2% participation rate
# - North Dakota has consistent lowest participation of 2% for all 3 years
#
# **ACT Lowest Participation Rate**
#
# - 2017 ACT: The last 4 places -> Maine with 8% participation rate, Rhode Island at 21%, New Hampshire and Delaware with 18%.
# - 2018 ACT: The last 4 places -> Maine with 7% participation rate, Rhode Island at 15%, New Hampshire at 16%, and Delaware at 17%.
# - 2019 ACT: The last 4 places -> Maine with 6% participation rate, Rhode Island at 12%, New Hampshire at 14%, and Delaware at 13%.
# -Maine, Rhode Island, New Hamshire, and Delaware appear to be consistently the lowest in the participation rate from 2017 to 2019. The participation rate of these 4 states also consistently decrease from 2017 to 2019.

# %% [markdown]
# ### Investigate SAT/ ACT participation rate trends from 2017 to 2019
# - Increasing/decreasing trend with 100% participation rate?
# - Increasing/decreasing trend with least participation rate?

# %% [markdown]
# ### SAT Participation rate (2017 to 2019) Visualization

# %%
final_sat_merged_participation = final_merged[['sat17_participation','sat18_participation','sat19_participation']]
final_sat_merged_participation.head()
# Out:
#    sat17_participation  sat18_participation  sat19_participation
# 0                 0.05                 0.06                 0.07
# 1                 0.38                 0.43                 0.41
# 2                 0.30                 0.29                 0.31
# 3                 0.03                 0.05                 0.06
# 4                 0.53                 0.60                 0.63

# %% [markdown]
# ### SAT Dataframe transformation with pandas melt function

# %%
final_sat_merged_participation= final_sat_merged_participation.melt(var_name='year', value_name='participation rate')
final_sat_merged_participation
# Out:
#                     year  participation rate
# 0    sat17_participation                0.05
# 1    sat17_participation                0.38
# 2    sat17_participation                0.30
# 3    sat17_participation                0.03
# 4    sat17_participation                0.53
# ..                   ...                 ...
# 148  sat19_participation                0.68
# 149  sat19_participation                0.70
# 150  sat19_participation                0.99
# 151  sat19_participation                0.03
# 152  sat19_participation                0.03
#
# [153 rows x 2 columns]

# %%
plt.subplots(figsize=(8, 8))
sns.boxplot(x='year', y="participation rate", data=final_sat_merged_participation).set_title('SAT Participation Rate Trend (2017-2019)');

# %% [markdown]
# #### Observation:
# SAT Participation rates have shown min, median, and interquartile (25%,75%) rates are increasing year over year. This makes sense as more and more states make it mandatory for high school students to sit for the SAT exam during recent years ([*source1*](https://blog.collegevine.com/states-that-require-sat/)). Some advantages of making SAT mandatory in states:
#
# - Streamlining national exams <br/>
# - Increasing access to the SAT, particularly for lower-income students <br/>
# - Inspiring some students to apply to college <br/>

# %%
final_merged[(final_merged['state']=='North Dakota')][['state','sat19_participation','act19_participation']]
# Out:
#            state  sat19_participation  act19_participation
# 34  North Dakota                 0.02                 0.96

# %% [markdown]
# #### Observation:
# North Nakota have the lowest SAT participation rate as most high school students take the ACT exam instead (96% participation)

# %% [markdown]
# ### ACT Participation rate (2017 to 2019) Visualization

# %%
final_act_merged_participation=final_merged[['act17_participation','act18_participation','act19_participation']]
final_act_merged_participation.head()
# Out:
#    act17_participation  act18_participation  act19_participation
# 0                 1.00                 1.00                 1.00
# 1                 0.65                 0.33                 0.38
# 2                 0.62                 0.66                 0.73
# 3                 1.00                 1.00                 1.00
# 4                 0.31                 0.27                 0.23

# %% [markdown]
# ### ACT Dataframe transformation with pandas melt function

# %%
final_act_merged_participation= final_act_merged_participation.melt(var_name='year', value_name='participation rate')

# %%
f, ax = plt.subplots(figsize=(8, 8))
sns.boxplot(x='year', y="participation rate", data=final_act_merged_participation).set_title('ACT Participation Rate Trend (2017-2019)');

# %% [markdown]
# #### Observation:
# ACT participation rates have shown min, median, and interquartile (25%) rates are consistently decreasing year over year. Logically it is understandable for ACT participation in the state to decrease if most of the high school students are taking SAT exams instead. Investigated below:

# %%
final_merged[final_merged['sat19_participation']==1][['state','sat19_participation','act19_participation']]
# Out:
#            state  sat19_participation  act19_participation
# 5       Colorado                  1.0                 0.27
# 6    Connecticut                  1.0                 0.22
# 7       Delaware                  1.0                 0.13
# 9        Florida                  1.0                 0.54
# 12         Idaho                  1.0                 0.31
# 13      Illinois                  1.0                 0.35
# 22      Michigan                  1.0                 0.19
# 39  Rhode Island                  1.0                 0.12

# %% [markdown]
# #### Observation:
# Delaware and Rhode Island have low ACT participation rates as most high school students take SAT exam instead (100% participation in 2019)

# %%
final_merged[(final_merged['state']=='Maine') | (final_merged['state']=='New Hampshire')][['state','sat19_participation','act19_participation']]
# Out:
#             state  sat19_participation  act19_participation
# 19          Maine                 0.99                 0.06
# 29  New Hampshire                 0.95                 0.14

# %% [markdown]
# #### Observation:
# Similarly, Maine and New Hampshire have low ACT participation rates as most high school students take SAT exam instead (>95% participation in 2019)

# %% [markdown]
# ### b) Do any states with 100% participation on a given test have a rate change year-to-year?

# %%
final_merged[(final_merged['sat17_participation']==1) & (final_merged['sat18_participation']<1)][['state','sat17_participation','sat18_participation','sat19_participation']]
# Out:
#                   state  sat17_participation  sat18_participation  \
# 8  District of Columbia                  1.0                 0.92
#
#    sat19_participation
# 8                 0.94

# %%
#final_merged[(final_merged['sat18_participation']==1) & (final_merged['sat19_participation']<1)][['state','sat17_participation','sat18_participation','sat19_participation']]

# %%
final_merged[(final_merged['act17_participation']==1) & (final_merged['act18_participation']<1)][['state','act17_participation','act18_participation','act19_participation']]
# Out:
#         state  act17_participation  act18_participation  act19_participation
# 5    Colorado                  1.0                 0.30                 0.27
# 23  Minnesota                  1.0                 0.99                 0.95

# %%
final_merged[(final_merged['act18_participation']==1) & (final_merged['act19_participation']<1)][['state','act17_participation','act18_participation','act19_participation']]
# Out:
#              state  act17_participation  act18_participation  \
# 25        Missouri                  1.0                  1.0
# 40  South Carolina                  1.0                  1.0
#
#     act19_participation
# 25                 0.82
# 40                 0.78

# %% [markdown]
# #### Observations:
#
# **SAT Observation**
#
# - States: District of Columbia, decrease from 100% (2017) to 92% (2018) and increasing to 94% (2019).
#
# **ACT Observation**
#
# - States: Colorado, decrease from 100% (2017) to 30% (2018) and increasing to 27% (2019). Minnesota, decrease from 100% (2017) to 99% (2018) and increasing to 95% (2019). Missouri, decrease from 100% (2018) to 82% (2019). South Carolina, decrease from 100% (2018) to 78% (2019).
#
# We see a sharp drop in the ACT participation rate for the state of Colorado from 2017 (100%) to 2019 (27%), investigated below:

# %%
print(final_merged[(final_merged['state']=='Colorado')][['state','sat17_participation','act17_participation']])
print(final_merged[(final_merged['state']=='Colorado')][['state','sat18_participation','act18_participation']])
print(final_merged[(final_merged['state']=='Colorado')][['state','sat19_participation','act19_participation']])
# Out:
#       state  sat17_participation  act17_participation
# 5  Colorado                 0.11                  1.0
#       state  sat18_participation  act18_participation
# 5  Colorado                  1.0                  0.3
#       state  sat19_participation  act19_participation
# 5  Colorado                  1.0                 0.27

# %% [markdown]
# #### Observation:
# We see that most of the high school students are taking SAT exam from 11% participation rate in 2017 to 100% for years 2018 and 2019. This may explain the drop in ACT exam participation.

# %% [markdown]
# ### c) Do any states show have >50% participation on *both* tests each year?

# %% [markdown]
# ### Year 2017

# %%
df_17 = final_merged[(final_merged['act17_participation']>0.5) & (final_merged['sat17_participation']>0.5)][['state','sat17_participation','act17_participation']]
df_17
# Out:
#       state  sat17_participation  act17_participation
# 9   Florida                 0.83                 0.73
# 10  Georgia                 0.61                 0.55
# 11   Hawaii                 0.55                 0.90

# %% [markdown]
# ### Year 2018

# %%
df_18 = final_merged[(final_merged['act18_participation']>0.5) & (final_merged['sat18_participation']>0.5)][['state','sat18_participation','act18_participation']]
df_18
# Out:
#              state  sat18_participation  act18_participation
# 9          Florida                 0.56                 0.66
# 10         Georgia                 0.70                 0.53
# 11          Hawaii                 0.56                 0.89
# 33  North Carolina                 0.52                 1.00
# 40  South Carolina                 0.55                 1.00

# %% [markdown]
# ### Year 2019

# %%
df_19 = final_merged[(final_merged['act19_participation']>0.5) & (final_merged['sat19_participation']>0.5)][['state','sat19_participation','act19_participation']]
df_19
# Out:
#              state  sat19_participation  act19_participation
# 9          Florida                 1.00                 0.54
# 11          Hawaii                 0.54                 0.80
# 33  North Carolina                 0.51                 1.00
# 40  South Carolina                 0.68                 0.78

# %%
intercept_df = pd.merge(df_17, df_18, how='inner', on=['state']).merge(df_19, how='inner', on=['state'])
intercept_df
# Out:
#      state  sat17_participation  act17_participation  sat18_participation  \
# 0  Florida                 0.83                 0.73                 0.56
# 1   Hawaii                 0.55                 0.90                 0.56
#
#    act18_participation  sat19_participation  act19_participation
# 0                 0.66                 1.00                 0.54
# 1                 0.89                 0.54                 0.80

# %% [markdown]
# #### Observation:
# Florida and Hawaii have consistently achieved >50% participation on *both* tests from 2017 to 2019

# %% [markdown]
# ###  d) Which state have the LOWEST COMBINED SAT & ACT Participation for the year of 2019?

# %%
final_merged['total_participation_19']=(final_merged['act19_participation']+final_merged['sat19_participation'])/2
df_participation_19 = final_merged[['state','act19_participation','sat19_participation','total_participation_19']]
df_participation_19.shape
# Out:
# (51, 4)

# %% [markdown]
# #### Filtering out states with participation > 0.7 for either ACT and SAT exam. This ensures states that have a statewide adoption of either SAT/ACT, (i.e. Participation rate of SAT = 100% but  Participation rate of ACT =0%) does not appear in our new data frame

# %%
df_participation_19=df_participation_19[(df_participation_19['act19_participation']<0.7) & (df_participation_19['sat19_participation']<0.7)]
df_participation_19.shape
# Out:
# (9, 4)

# %%
df_bottom_participation_19 = df_participation_19.sort_values(['total_participation_19'],ascending=True)

# %%
df_bottom_participation_19 = df_bottom_participation_19[['state','act19_participation','sat19_participation','total_participation_19']]
df_bottom_participation_19.head()
# Out:
#          state  act19_participation  sat19_participation  \
# 15        Iowa                 0.66                 0.03
# 1       Alaska                 0.38                 0.41
# 31  New Mexico                 0.63                 0.18
# 4   California                 0.23                 0.63
# 45     Vermont                 0.20                 0.66
#
#     total_participation_19
# 15                   0.345
# 1                    0.395
# 31                   0.405
# 4                    0.430
# 45                   0.430

# %% [markdown]
# ### e) Which states have the highest and lowest mean total/composite scores for 2017, 2018, and 2019 SAT and ACT exams?

# %% [markdown]
# ### SAT Exam

# %% [markdown]
# #### 2017 SAT Exam Ranking by States (Top 5)

# %%
df_exam_top_sat_17 = final_merged.sort_values('sat17_total',ascending=False)
df_exam_top_sat_17 = df_exam_top_sat_17[['state','sat17_ebrw','sat17_math','sat17_total']].head()
df_exam_top_sat_17
# Out:
#         state  sat17_ebrw  sat17_math  sat17_total
# 23  Minnesota         644         651         1295
# 49  Wisconsin         642         649         1291
# 15       Iowa         641         635         1275
# 25   Missouri         640         631         1271
# 16     Kansas         632         628         1260

# %% [markdown]
# #### 2017 SAT Exam Ranking by States (Bottom 5)

# %%
df_exam_bottom_sat_17 = final_merged.sort_values('sat17_total',ascending=True)
df_exam_bottom_sat_17 = df_exam_bottom_sat_17[['state','sat17_ebrw','sat17_math','sat17_total']].head()
df_exam_bottom_sat_17
# Out:
#                    state  sat17_ebrw  sat17_math  sat17_total
# 8   District of Columbia         482         468          950
# 7               Delaware         503         492          996
# 12                 Idaho         513         493         1005
# 22              Michigan         509         495         1005
# 19                 Maine         513         499         1012

# %% [markdown]
# #### 2018 SAT Exam Ranking by States (Top 5)

# %%
df_exam_top_sat_18 = final_merged.sort_values('sat18_total',ascending=False)
df_exam_top_sat_18 = df_exam_top_sat_18[['state','sat18_ebrw','sat18_math','sat18_total']].head()
df_exam_top_sat_18
# Out:
#            state  sat18_ebrw  sat18_math  sat18_total
# 23     Minnesota         643         655         1298
# 49     Wisconsin         641         653         1294
# 34  North Dakota         640         643         1283
# 15          Iowa         634         631         1265
# 16        Kansas         633         631         1265

# %% [markdown]
# #### 2018 SAT Exam Ranking by States (Bottom 5)

# %%
df_exam_bottom_sat_18 = final_merged.sort_values('sat18_total',ascending=True)
df_exam_bottom_sat_18 = df_exam_bottom_sat_18[['state','sat18_ebrw','sat18_math','sat18_total']].head()
df_exam_bottom_sat_18
# Out:
#                    state  sat18_ebrw  sat18_math  sat18_total
# 8   District of Columbia         497         480          977
# 7               Delaware         505         492          998
# 48         West Virginia         513         486          999
# 12                 Idaho         508         493         1001
# 44                  Utah         480         530         1010

# %% [markdown]
# #### 2019 SAT Exam Ranking by States (Top 5)

# %%
df_exam_top_sat_19 = final_merged.sort_values('sat19_total',ascending=False)
df_exam_top_sat_19 = df_exam_top_sat_19[['state','sat19_ebrw','sat19_math','sat19_total']].head()
df_exam_top_sat_19
# Out:
#            state  sat19_ebrw  sat19_math  sat19_total
# 23     Minnesota         636         648         1284
# 49     Wisconsin         635         648         1283
# 41  South Dakota         633         635         1268
# 34  North Dakota         627         636         1263
# 27      Nebraska         628         631         1260

# %% [markdown]
# #### 2019 SAT Exam Ranking by States (Bottom 5)

# %%
df_exam_bottom_sat_19 = final_merged.sort_values('sat19_total',ascending=True)
df_exam_bottom_sat_19 = df_exam_bottom_sat_19[['state','sat19_ebrw','sat19_math','sat19_total']].head()
df_exam_bottom_sat_19
# Out:
#                    state  sat19_ebrw  sat19_math  sat19_total
# 48         West Virginia         483         460          943
# 36              Oklahoma         490         472          963
# 8   District of Columbia         495         480          975
# 7               Delaware         499         486          985
# 12                 Idaho         505         488          993

# %% [markdown]
# #### SAT Observations from 2017 to 2019

# %%
intercept_top_sat_df = pd.merge(df_exam_top_sat_17, df_exam_top_sat_18, how='inner', on=['state']).merge(df_exam_top_sat_19, how='inner', on=['state'])
intercept_top_sat_df[['state','sat17_total','sat18_total','sat19_total']]
# Out:
#        state  sat17_total  sat18_total  sat19_total
# 0  Minnesota         1295         1298         1284
# 1  Wisconsin         1291         1294         1283

# %%
intercept_bottom_sat_df = pd.merge(df_exam_bottom_sat_17, df_exam_bottom_sat_18, how='inner', on=['state']).merge(df_exam_bottom_sat_19, how='inner', on=['state'])
intercept_bottom_sat_df[['state','sat17_total','sat18_total','sat19_total']]
# Out:
#                   state  sat17_total  sat18_total  sat19_total
# 0  District of Columbia          950          977          975
# 1              Delaware          996          998          985
# 2                 Idaho         1005         1001          993

# %% [markdown]
# #### Observations:
# - Minnesota and Wisconsin have been the top-performing states for SAT exams from 2017 to 2019.
#
# - District of Columbia, Delaware, and Idaho has consistently ranked the bottom from 2017 to 2019.

# %% [markdown]
# ### ACT Exam

# %% [markdown]
# #### 2017 ACT Exam Ranking by States (Top 5)

# %%
df_exam_top_act_17 = final_merged.sort_values('act17_composite',ascending=False)
df_exam_top_act_17 = df_exam_top_act_17[['state','act17_english','act17_math','act17_reading','act17_science','act17_composite']].head()
df_exam_top_act_17
# Out:
#                    state  act17_english  act17_math  act17_reading  \
# 29         New Hampshire           25.4        25.1           26.0
# 21         Massachusetts           25.4        25.3           25.9
# 6            Connecticut           25.5        24.6           25.6
# 19                 Maine           24.2        24.0           24.8
# 8   District of Columbia           24.4        23.5           24.9
#
#     act17_science  act17_composite
# 29           24.9             25.5
# 21           24.7             25.4
# 6            24.6             25.2
# 19           23.7             24.3
# 8            23.5             24.2

# %% [markdown]
# #### 2017 ACT Exam Ranking by States (Bottom 5)

# %%
df_exam_bottom_act_17 = final_merged.sort_values('act17_composite',ascending=True)
df_exam_bottom_act_17 = df_exam_bottom_act_17[['state','act17_english','act17_math','act17_reading','act17_science','act17_composite']].head()
df_exam_bottom_act_17
# Out:
#              state  act17_english  act17_math  act17_reading  act17_science  \
# 28          Nevada           16.3        18.0           18.1           18.2
# 24     Mississippi           18.2        18.1           18.8           18.8
# 40  South Carolina           17.5        18.6           19.1           18.9
# 11          Hawaii           17.8        19.2           19.2           19.3
# 33  North Carolina           17.8        19.3           19.6           19.3
#
#     act17_composite
# 28             17.8
# 24             18.6
# 40             18.7
# 11             19.0
# 33             19.1

# %% [markdown]
# #### 2018 ACT Exam Ranking by States (Top 5)

# %%
df_exam_top_act_18 = final_merged.sort_values('act18_composite',ascending=False)
df_exam_top_act_18 = df_exam_top_act_18[['state','act18_composite']].head()
df_exam_top_act_18
# Out:
#             state  act18_composite
# 6     Connecticut             25.6
# 21  Massachusetts             25.5
# 29  New Hampshire             25.1
# 32       New York             24.5
# 22       Michigan             24.2

# %% [markdown]
# #### 2018 ACT Exam Ranking by States (Bottom 5)

# %%
df_exam_bottom_act_18 = final_merged.sort_values('act18_composite',ascending=True)
df_exam_bottom_act_18 = df_exam_bottom_act_18[['state','act18_composite']].head()
df_exam_bottom_act_18
# Out:
#              state  act18_composite
# 28          Nevada             17.7
# 40  South Carolina             18.3
# 24     Mississippi             18.6
# 11          Hawaii             18.9
# 0          Alabama             19.1

# %% [markdown]
# #### 2019 ACT Exam Ranking by States (Top 5)

# %%
df_exam_top_act_19 = final_merged.sort_values('act19_composite',ascending=False)
df_exam_top_act_19 = df_exam_top_act_19[['state','act19_composite']].head()
df_exam_top_act_19
# Out:
#             state  act19_composite
# 21  Massachusetts             25.5
# 6     Connecticut             25.5
# 29  New Hampshire             25.0
# 39   Rhode Island             24.7
# 32       New York             24.5

# %% [markdown]
# #### 2019 ACT Exam Ranking by States (Bottom 5)

# %%
df_exam_bottom_act_19 = final_merged.sort_values('act19_composite',ascending=True)
df_exam_bottom_act_19 = df_exam_bottom_act_19[['state','act19_composite']].head()
df_exam_bottom_act_19
# Out:
#              state  act19_composite
# 28          Nevada             17.9
# 24     Mississippi             18.4
# 40  South Carolina             18.8
# 18       Louisiana             18.8
# 0          Alabama             18.9

# %% [markdown]
# #### ACT Observations from 2017 to 2019

# %%
intercept_top_act_df = pd.merge(df_exam_top_act_17, df_exam_top_act_18, how='inner', on=['state']).merge(df_exam_top_act_19, how='inner', on=['state'])
intercept_top_act_df[['state','act17_composite','act18_composite','act19_composite']]
# Out:
#            state  act17_composite  act18_composite  act19_composite
# 0  New Hampshire             25.5             25.1             25.0
# 1  Massachusetts             25.4             25.5             25.5
# 2    Connecticut             25.2             25.6             25.5

# %%
intercept_bottom_act_df = pd.merge(df_exam_bottom_act_17, df_exam_bottom_act_18, how='inner', on=['state']).merge(df_exam_bottom_act_19, how='inner', on=['state'])
intercept_bottom_act_df[['state','act17_composite','act18_composite','act19_composite']]
# Out:
#             state  act17_composite  act18_composite  act19_composite
# 0          Nevada             17.8             17.7             17.9
# 1     Mississippi             18.6             18.6             18.4
# 2  South Carolina             18.7             18.3             18.8

# %% [markdown]
# #### Observations:
# - New Hampshire, Massachusetts, and Connecticut states have been the top performing states for ACT from 2017 to 2019.
#
# - District of Nevada, Mississippi and South Carolina have consistently ranked the bottom from 2017 to 2019.

# %% [markdown]
# ### f) Which state have the highest/lowest NORMALIZED SCORE from both SAT and ACT exam for the year of 2019?

# %%
final_merged['normalized_sat_act_score']=final_merged['act19_composite']/36+final_merged['sat19_total']/1600

# %% [markdown]
# #### Top 5 States with Highest Normalized Score

# %%
df_top_states_19 = final_merged.sort_values(['normalized_sat_act_score'],ascending=False)
df_top_states_19 = df_top_states_19[['state','act19_composite','sat19_total','normalized_sat_act_score']].head()
df_top_states_19.head(5)
# Out:
#             state  act19_composite  sat19_total  normalized_sat_act_score
# 21  Massachusetts             25.5         1120                  1.408333
# 23      Minnesota             21.4         1284                  1.396944
# 41   South Dakota             21.6         1268                  1.392500
# 15           Iowa             21.6         1244                  1.377500
# 46       Virginia             24.0         1119                  1.366042

# %% [markdown]
# #### Bottom 5 States with Highest Normalized Score

# %%
df_bottom_states_19 = final_merged.sort_values(['normalized_sat_act_score'],ascending=True)
df_bottom_states_19 = df_bottom_states_19[['state','act19_composite','sat19_total','normalized_sat_act_score']]
df_bottom_states_19.head(5)
# Out:
#              state  act19_composite  sat19_total  normalized_sat_act_score
# 36        Oklahoma             18.9          963                  1.126875
# 40  South Carolina             18.8         1030                  1.165972
# 48   West Virginia             20.8          943                  1.167153
# 9          Florida             20.1          999                  1.182708
# 31      New Mexico             19.3         1073                  1.206736

# %% [markdown]
# ### g. From the additional dataset, which states have the highest/ lowest poverty rate/ economically disadvantaged high school students etc?

# %% [markdown]
# ### Poverty (2018-2019) Comparison

# %%
df_highest_poverty = economical_summary_df.sort_values(['2_years_avg_proverty_rate'],ascending=False)
df_lowest_poverty = economical_summary_df.sort_values(['2_years_avg_proverty_rate'],ascending=True)

# %%
df_highest_poverty.head(3)
# Out:
#           state  2_years_avg_proverty_rate  students_disabilities  \
# 24  Mississippi                       19.4                   42.2
# 18    Louisiana                       18.4                   64.7
# 31   New Mexico                       16.0                   64.7
#
#     economically_disadvantaged  homeless enrolled
# 24                        82.2               70.0
# 18                        74.4               66.0
# 31                        70.0               52.0

# %%
df_lowest_poverty.head(3)
# Out:
#             state  2_years_avg_proverty_rate  students_disabilities  \
# 29  New Hampshire                        4.9                   72.0
# 23      Minnesota                        6.8                   63.0
# 7        Delaware                        6.9                   73.0
#
#     economically_disadvantaged  homeless enrolled
# 29                        77.2               64.0
# 23                        71.1               49.0
# 7                         82.0               73.0

# %% [markdown]
# #### Observations:
# - New Hampshire, Minnesota, and Delaware are ranked the lowest in poverty from 2018 to 2019.
#
# - Mississippi, Louisiana, and New Mexico are ranked the highest in poverty from 2018 to 2019.

# %% [markdown]
# ### Public High School Average Graduation Rate for Economically Disadvantaged (2018-2019) Students Comparison

# %%
df_highest_ed = economical_summary_df.sort_values(['economically_disadvantaged'],ascending=False)
df_lowest_ed = economical_summary_df.sort_values(['economically_disadvantaged'],ascending=True)

# %%
df_highest_ed.head(5)
# Out:
#        state  2_years_avg_proverty_rate  students_disabilities  \
# 17  Kentucky                       14.6                   75.5
# 0    Alabama                       14.4                   69.6
# 43     Texas                       12.4                   77.9
# 15      Iowa                        9.2                   76.1
# 3   Arkansas                       15.0                   82.6
#
#     economically_disadvantaged  homeless enrolled
# 17                        87.8               16.0
# 0                         87.4               81.0
# 43                        87.2               79.8
# 15                        85.2               75.0
# 3                         84.8               76.0

# %%
df_lowest_ed.head(5)
# Out:
#                    state  2_years_avg_proverty_rate  students_disabilities  \
# 8   District of Columbia                       13.6                   51.0
# 31            New Mexico                       16.0                   64.7
# 22              Michigan                       10.3                   57.8
# 5               Colorado                        9.2                   59.2
# 35                  Ohio                       12.1                   48.0
#
#     economically_disadvantaged  homeless enrolled
# 8                         58.6               49.0
# 31                        70.0               52.0
# 22                        70.8               58.4
# 5                         70.9               55.6
# 35                        71.0               54.0

# %% [markdown]
# #### Observations:
# - Kentucky, Alabama, and Texas are ranked the highest in Average College Graduation Rate for economically disadvantaged students from 2018 to 2019.
#
# - District of Columbia, New Mexico, and Michigan are ranked the lowest in Average College Graduation Rate for economically disadvantaged students from 2018 to 2019.

# %% [markdown]
# ### Finding intercept between highest poverty states with lowest graduation rate for economically disadvantaged students

# %%
df_lowest15_ed = df_lowest_ed.head(15)
df_highest15_poverty = df_highest_poverty.head(15)

# %%
intercept_econs_df = pd.merge(df_lowest15_ed, df_highest15_poverty, how='inner', on=['state'])
intercept_econs_df[['state']]
# Out:
#                   state
# 0  District of Columbia
# 1            New Mexico
# 2             Louisiana

# %% [markdown]
# #### Observations:
# District of Columbia, New Mexico, and Louisiana are ranked the highest in poverty and lowest rate of graduation for high school students with economical disadvantage from 2018 to 2019. This may be crucial in determining which state to provide state funding as financial aids to students. To investigate correlations between participation rate/exam scores with poverty/economically disadvantaged students later.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# ### 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.

# %% [markdown]
# #### Using Seaborn's heatmap to examine correlations between 2017 SAT VS ACT participation rate

# %%
# Clean dataframe to better identify relationship of potential interest
df_heatmap = final_merged[['sat17_participation','sat18_participation','sat19_participation','act17_participation','act18_participation','act19_participation']]

# %%
plt.subplots(figsize=(15, 8))
mask = np.zeros_like(df_heatmap.corr())
mask[np.triu_indices_from(mask)] = True

with sns.axes_style("dark"):
    sns.heatmap(df_heatmap.corr(), mask = mask, square = True, annot = True, fmt = ".2f", vmin = -1, vmax = 1, linewidths = .5)

plt.show()

# %% [markdown]
# #### Observation:
# Previously, we have observed ACT participation rates have consistently decreased while SAT participation rates increased year over year. The assumption previously make was was that most of the high school students are taking SAT exams instead. This assumption is supported by the heatmap plot above, which gave us a strong inverse correlation between SAT and ACT participation rates for each year.

# %% [markdown]
# #### Using Seaborn's heatmap to examine correlations SAT / ACT participation rate VS Total / Composite Score for 2018 and 2019

# %%
# Clean dataframe to better identify relationship of potential interest
df_heatmap_17 = final_merged[['sat17_participation','sat17_total','act17_participation','act17_composite']]

# %%
plt.subplots(figsize=(15, 8))
mask = np.zeros_like(df_heatmap_17.corr())
mask[np.triu_indices_from(mask)] = True

with sns.axes_style("dark"):
    sns.heatmap(df_heatmap_17.corr(), mask = mask, square = True, annot = True, fmt = ".2f", vmin = -1, vmax = 1, linewidths = .5).set_title("2017 Participation Rate VS ACT/SAT Scores")

plt.show();

# %% [markdown]
# #### 3 INTERESTING OBSERVATIONS:
# - Strong inverse correlation (-0.86) between ACT composite score and ACT participation rate; higher ACT participation   rate, lower ACT composite score.
# - Similar inverse correlation (-0.87) is observed between SAT total score and SAT participation rate; higher SAT        participation rate, lower SAT total score
# - Strong inverse correlation between ACT participation rate and SAT participation rate which we have observed earlier
#
# #### Let's check out 2018 and 2019 data to see if we observe the same trend

# %%
df_heatmap_18 = final_merged[['sat18_participation','sat18_total','act18_participation','act18_composite']]
df_heatmap_19 = final_merged[['sat19_participation','sat19_total','act19_participation','act19_composite']]

# %%
plt.subplots(figsize=(15, 8))
mask = np.zeros_like(df_heatmap_18.corr())
mask[np.triu_indices_from(mask)] = True

with sns.axes_style("dark"):
    sns.heatmap(df_heatmap_18.corr(), mask = mask, square = True, annot = True, fmt = ".2f", vmin = -1, vmax = 1, linewidths = .5).set_title("2018 Participation Rate VS ACT/SAT Scores")

plt.show();

# %%
plt.subplots(figsize=(15, 8))
mask = np.zeros_like(df_heatmap_19.corr())
mask[np.triu_indices_from(mask)] = True

with sns.axes_style("dark"):
    sns.heatmap(df_heatmap_19.corr(), mask = mask, square = True, annot = True, fmt = ".2f", vmin = -1, vmax = 1, linewidths = .5).set_title("2019 Participation Rate VS ACT/SAT Scores")

plt.show();

# %% [markdown]
# #### All 3 trends seen in 2017 data is also reflected in 2018 and 2019 data
# - Higher ACT participation rate, lower ACT composite score.
# - Higher SAT participation rate, lower SAT total score.
# - ACT participation rate inverse correlation with SAT participation rate
#
# These inverse correlation between participation rate and exam scores are expected as statewide adoption of SAT/ACT exam means greater participation of students of different social economically status, cohort differences and academic achievements ([*source2*](https://www.act.org/content/dam/act/unsecured/documents/Statewide-Adoption.pdf)). Senior college students who are not motivated to go to college will have to equally take the exam.
#
# As a result, an increasing percentage of low/mid-tier students lower the overall state average with statewide adoption of ACT/SAT ([*source3*](https://medium.com/@james.dargan/participation-skews-state-averages-f68969371a01)). Conversely, lower participation rates tend to have high exam scores as self-selected elite students choose to pursue admission to elite universities voluntarily.

# %%
#The Pearson correlation coefficient [1] measures the linear relationship between two datasets. The calculation of the p-value relies on the assumption that each dataset is normally distributed. 
#However, datasets are not nomrally distributed and thus, we are unable to use this method to determine P-value.
#import scipy
#scipy.stats.pearsonr(final_merged.sat19_participation,final_merged.sat19_total)

# %% [markdown]
# ### 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.

# %% [markdown]
# ### Plotting histogram of SAT/ACT participation rates from 2017-2019

# %%
# Set up the matplotlib figure
# Set up the matplotlib figure
sat_color = "#32b165"
act_color = "#a38cf4"
plt.figure(figsize = (16,9))

ax=plt.subplot(2, 3, 1)
ax.set_title('SAT participation rates (2017)')
sns.histplot(final_merged.sat17_participation, bins=10, color=sat_color,kde=True, ax=ax).set(xlim=(0,1),ylim=(0,25))
ax.set_xlabel('SAT Participation Rates')
ax.set_ylabel('Number of states');

ax=plt.subplot(2, 3, 2)
ax.set_title('SAT participation rates (2018)')
sns.histplot(final_merged.sat18_participation, bins=10, color=sat_color,kde=True, ax=ax).set(xlim=(0,1),ylim=(0,25))
ax.set_xlabel('SAT Participation Rates')
ax.set_ylabel('Number of states');

ax=plt.subplot(2, 3, 3)
ax.set_title('SAT participation rates (2019)')
sns.histplot(final_merged.sat19_participation, bins=10, color=sat_color,kde=True, ax=ax).set(xlim=(0,1),ylim=(0,25))
ax.set_xlabel('SAT Participation Rates')
ax.set_ylabel('Number of states');

ax=plt.subplot(2, 3, 4)
ax.set_title('ACT participation rates (2017)')
sns.histplot(final_merged.act17_participation, bins=10, color=act_color,kde=True, ax=ax).set(xlim=(0,1),ylim=(0,25))
ax.set_xlabel('ACT Participation Rates')
ax.set_ylabel('Number of states');

ax=plt.subplot(2, 3, 5)
ax.set_title('ACT participation rates (2018)')
sns.histplot(final_merged.act18_participation, bins=10, color=act_color,kde=True, ax=ax).set(xlim=(0,1),ylim=(0,25))
ax.set_xlabel('ACT Participation Rates')
ax.set_ylabel('Number of states');

ax=plt.subplot(2, 3, 6)
ax.set_title('ACT participation rates (2019)')
sns.histplot(final_merged.act19_participation, bins=10, color=act_color,kde=True, ax=ax).set(xlim=(0,1),ylim=(0,25))
ax.set_xlabel('ACT Participation Rates')
ax.set_ylabel('Number of states');

# %% [markdown]
# ### Plotting histogram of SAT/ACT exam score from 2017-2019

# %%
# Set up the matplotlib figure
sat_color = "#32b165"
act_color = "#a38cf4"
plt.figure(figsize = (16,9))

ax=plt.subplot(2, 3, 1)
ax.set_title('SAT Total Score (2017)')
sns.histplot(final_merged.sat17_total, bins=10, color=sat_color,kde=True, ax=ax).set(xlim=(900,1300),ylim=(0,13))
ax.set_xlabel('SAT Total Score')
ax.set_ylabel('Number of states');

ax=plt.subplot(2, 3, 2)
ax.set_title('SAT Total Score (2018)')
sns.histplot(final_merged.sat18_total, bins=10, color=sat_color,kde=True, ax=ax).set(xlim=(900,1300),ylim=(0,13))
ax.set_xlabel('SAT Total Score')
ax.set_ylabel('Number of states');

ax=plt.subplot(2, 3, 3)
ax.set_title('SAT Total Score (2019)')
sns.histplot(final_merged.sat19_total, bins=10, color=sat_color,kde=True, ax=ax).set(xlim=(900,1300),ylim=(0,13))
ax.set_xlabel('SAT Total Score')
ax.set_ylabel('Number of states');

ax=plt.subplot(2, 3, 4)
ax.set_title('ACT Composite Score (2017)')
sns.histplot(final_merged.act17_composite, bins=10, color=act_color,kde=True, ax=ax).set(xlim=(17,27),ylim=(0,12))
ax.set_xlabel('ACT Composite Score')
ax.set_ylabel('Number of states');

ax=plt.subplot(2, 3, 5)
ax.set_title('ACT Composite Score (2018)')
sns.histplot(final_merged.act18_composite, bins=10, color=act_color,kde=True, ax=ax).set(xlim=(17,27),ylim=(0,12))
ax.set_xlabel('ACT Composite Score')
ax.set_ylabel('Number of states');

ax=plt.subplot(2, 3, 6)
ax.set_title('ACT Composite Score (2019)')
sns.histplot(final_merged.act19_composite, bins=10, color=act_color,kde=True, ax=ax).set(xlim=(17,27),ylim=(0,12))
ax.set_xlabel('ACT Composite Score')
ax.set_ylabel('Number of states');

# %% [markdown]
# #### Observation:
# The histograms for participation and exam score data shows that they are not normally distributed. Statistical evidence below, following Kolmogorov Smirnov Statistic, which follows a Kolmogorov distribution if the null hypothesis is true. Distribution is considered norm if p-value>0.05.

# %%
from scipy.stats import kstest, norm

ks_statistic, p_value = kstest(final_merged.sat19_participation, 'norm')

if p_value < 0.05:
 print('\nDistribution is not normal.')
else:
 print('P-value =', p_value, '\nZ-score =', ks_statistic, '\nDistribution is normal')
# Out:
# Distribution is not normal.

# %%
ks_statistic, p_value = kstest(final_merged.act19_participation, 'norm')

if p_value < 0.05:
 print('\nDistribution is not normal.')
else:
 print('P-value =', p_value, '\nZ-score =', ks_statistic, '\nDistribution is normal')
# Out:
# Distribution is not normal.

# %%
ks_statistic, p_value = kstest(final_merged.sat19_total, 'norm')

if p_value < 0.05:
 print('\nDistribution is not normal.')
else:
 print('P-value =', p_value, '\nZ-score =', ks_statistic, '\nDistribution is normal')
# Out:
# Distribution is not normal.

# %%
k, p = stats.normaltest(final_merged.act19_composite)

ks_statistic, p_value = kstest(final_merged.act19_composite, 'norm')

if p_value < 0.05:
 print('\nDistribution is not normal.')
else:
 print('P-value =', p_value, '\nZ-score =', ks_statistic, '\nDistribution is normal')
# Out:
# Distribution is not normal.

# %% [markdown]
# ### 3. Plot and interpret boxplots.

# %% [markdown]
# ### Investigate SAT/ ACT participation rate trends from 2017 to 2019 (As seen in part 2)

# %%
plt.subplots(figsize=(8, 8))
sns.boxplot(x='year', y="participation rate", data=final_sat_merged_participation).set_title('SAT Participation Rate Trend (2017-2019)');

# %% [markdown]
# #### Observation:
# SAT Participation rates have shown min, median, and interquartile (25%,75%) rates are increasing year over year. This is logically sound as more and more states make it mandatory for high school students to sit for the SAT exam during recent years. Some advantages of making SAT mandatory in the state ([*source4*](https://blog.collegevine.com/states-that-require-sat/)):

# %%
f, ax = plt.subplots(figsize=(8, 8))
sns.boxplot(x='year', y="participation rate", data=final_act_merged_participation).set_title('ACT Participation Rate Trend (2017-2019)');

# %% [markdown]
# #### Observation:
# ACT participation rates have shown min, median, and interquartile (25%) rates are consistently decreasing year over year. Logically it would make sense for ACT participation in the state to decrease if most of the high school students are taking SAT exams instead. The heatmap plotted previously also shows a strong inverse correlation between act and sat participation which supports this observation.

# %%
final_merged.head()
# Out:
#         state  sat17_participation  sat17_ebrw  sat17_math  sat17_total  \
# 0     Alabama                 0.05         593         572         1165
# 1      Alaska                 0.38         547         533         1080
# 2     Arizona                 0.30         563         553         1116
# 3    Arkansas                 0.03         614         594         1208
# 4  California                 0.53         531         524         1055
#
#    act17_participation  act17_english  act17_math  act17_reading  \
# 0                 1.00           18.9        18.4           19.7
# 1                 0.65           18.7        19.8           20.4
# 2                 0.62           18.6        19.8           20.1
# 3                 1.00           18.9        19.0           19.7
# 4                 0.31           22.5        22.7           23.1
#
#    act17_science  ...  act18_participation  act18_composite  \
# 0           19.4  ...                 1.00             19.1
# ...

# %%
ACT_scores = final_merged[["act17_composite", "act18_composite", "act19_composite"]]
SAT_scores = final_merged[["sat17_total", "sat18_total", "sat19_total"]]

SAT_scores.head()
# Out:
#    sat17_total  sat18_total  sat19_total
# 0         1165         1166         1143
# 1         1080         1106         1097
# 2         1116         1149         1134
# 3         1208         1169         1141
# 4         1055         1076         1065

# %%
# Set up the matplotlib figure
f, axes = plt.subplots(ncols=2, figsize=(16, 9))

ax=axes[0]
ax.set_title('SAT Total Score (2017-2019)')
final_merged.boxplot(['sat17_total','sat18_total','sat19_total'], ax=ax)
ax.set_ylabel('SAT Total Score');

ax=axes[1]
ax.set_title('ACT Composite Score (2017-2019)')
final_merged.boxplot(['act17_composite','act18_composite','act19_composite'], ax=ax)
ax.set_ylabel('ACT Composite Score');

# %% [markdown]
# #### Observation:
# Not much can be interpreted from comparing the trends of the total/composite scores from 2017-2019 aside from the fact that there is a slightly wider range of SAT scores in 2019 as compared to 2017 and 2018 data. The medium score is also slightly lower, which we have explained previously under the heatmap chart.

# %% [markdown]
# ### 4. Plot and interpret scatter plots.

# %% [markdown]
# ### Investigate SAT VS ACT participation rate trends from 2017 to 2019 with scatter plot

# %%
# Set up the matplotlib figure
sns.set_color_codes()
plt.figure(figsize = (18,15))

ax=plt.subplot(2, 3, 1)
ax.set_title("Participation rates for ACT Exam VS SAT exam (2017)");
sns.regplot(x='sat17_participation', y='act17_participation', data=final_merged, color='r', ax=ax)
ax.set_xlabel("SAT Participation Rate")
ax.set_ylabel("ACT Participation Rate")

ax=plt.subplot(2, 3, 2)
ax.set_title("Participation rates for ACT Exam VS SAT exam (2018)");
sns.regplot(x='sat18_participation', y='act18_participation', data=final_merged, color='g', ax=ax)
ax.set_xlabel("SAT Participation Rate")
ax.set_ylabel("ACT Participation Rate")

ax=plt.subplot(2, 3, 3)
ax.set_title("Participation rates for ACT Exam VS SAT exam (2019)");
sns.regplot(x='sat19_participation', y='act19_participation', data=final_merged, color='m', ax=ax)
ax.set_xlabel("SAT Participation Rate")
ax.set_ylabel("ACT Participation Rate")
# Out:
# Text(0, 0.5, 'ACT Participation Rate')

# %% [markdown]
# #### Observation:
# ACT partcipation rates have an inverse correlation with SAT participation rate (as seen and briefly explained in previous sections)

# %%
### Investigate SAT/ACT participation rate VS Total/Composite scores from 2017 to 2019 with scatter plot

# %%
# Set up the matplotlib figure
sns.set_color_codes()
plt.figure(figsize = (18,15))

ax=plt.subplot(2, 3, 1)
ax.set_title("SAT Participation rates VS Total Score (2017)");
sns.regplot(x='sat17_participation', y='sat17_total', data=final_merged, color='r', ax=ax)
ax.set_xlabel("SAT Participation Rate")
ax.set_ylabel("SAT Total Score")

ax=plt.subplot(2, 3, 2)
ax.set_title("SAT Participation rates VS Total Score (2018)");
sns.regplot(x='sat18_participation', y='sat18_total', data=final_merged, color='g', ax=ax)
ax.set_xlabel("SAT Participation Rate")
ax.set_ylabel("SAT Total Score")

ax=plt.subplot(2, 3, 3)
ax.set_title("SAT Participation rates VS Total Score (2019)");
sns.regplot(x='sat19_participation', y='sat19_total', data=final_merged, color='b', ax=ax)
ax.set_xlabel("SAT Participation Rate")
ax.set_ylabel("SAT Total Score")

ax=plt.subplot(2, 3, 4)
ax.set_title("ACT Participation rates VS Composite Score (2017)");
sns.regplot(x='act17_participation', y='act17_composite', data=final_merged, color='r', ax=ax)
ax.set_xlabel("ACT Participation Rate")
ax.set_ylabel("ACT Composite Score")

ax=plt.subplot(2, 3, 5)
ax.set_title("ACT Participation rates VS Composite Score (2018)");
sns.regplot(x='act18_participation', y='act18_composite', data=final_merged, color='r', ax=ax)
ax.set_xlabel("ACT Participation Rate")
ax.set_ylabel("ACT Composite Score")

ax=plt.subplot(2, 3, 6)
ax.set_title("ACT Participation rates VS Composite Score (2019)");
sns.regplot(x='act19_participation', y='act19_composite', data=final_merged, color='b', ax=ax)
ax.set_xlabel("ACT Participation Rate")
ax.set_ylabel("ACT Total Score")
# Out:
# Text(0, 0.5, 'ACT Total Score')

# %% [markdown]
# #### Observation:
# ACT/SAT partcipation rates have an inverse correlation with total/composite score (as seen in previous sections)

# %% [markdown]
# ### Going back to our external dataset and address our problem statement of how socioeconomic factors impact the performance of national exams

# %%
economical_summary_normalized19_df = economical_summary_df.merge(final_merged[['state','act19_participation','act19_composite','sat19_participation','sat19_total','normalized_sat_act_score']], how = 'left', on = ('state').lower())

# %%
economical_summary_normalized19_df.describe()
# Out:
#        2_years_avg_proverty_rate  students_disabilities  \
# count                  51.000000              51.000000
# mean                   10.841176              67.843137
# std                     2.930541               8.713880
# min                     4.900000              42.200000
# 25%                     8.950000              62.950000
# 50%                    10.300000              69.600000
# 75%                    12.450000              73.450000
# max                    19.400000              82.600000
#
#        economically_disadvantaged  homeless enrolled  act19_participation  \
# count                   51.000000          51.000000            51.000000
# mean                    78.282353          65.162745             0.586667
# std                      5.438813          11.218858             0.345159
# min                     58.600000          16.000000             0.060000
# 25%                     74.850000          59.150000             0.245000
# ...

# %%
plt.subplots(figsize=(15, 8))
mask = np.zeros_like(economical_summary_normalized19_df.corr())
mask[np.triu_indices_from(mask)] = True

with sns.axes_style("dark"):
    sns.heatmap(economical_summary_normalized19_df.corr(), mask = mask, square = True, annot = True, fmt = ".2f", vmin = -1, vmax = 1, linewidths = .5)

plt.show()

# %% [markdown]
# #### A FEW INTERESTING OBSERVATIONS FROM ABOVE HEATMAP:
# - Moderate inverse correlation (-0.53) between 2019 normalized exam scores and poverty rate; higher normalized exam scores, lower poverty rate at that state.
#
# - Moderate direct correlation (0.36) is observed between the graduation rate of economically disadvantaged high school students VS graduation rate of homeless students enrolled. This makes logical sense as homeless students tend to be poorer in their financial backgrounds.
#
# - Moderate direct correlation (0.55) is observed between the graduation rate of economically disadvantaged high school students VS graduation rate of students with disabilities for years of 2018-2019.
#
# - Interestingly, the participation rate for both ACT and SAT in 2019 give a conflicting moderate correlation with poverty     rate; increase in the poverty rate, an increase in act19 participation but a decrease in sat19 participation.
#
# - Similarly, the participation rate for both ACT and SAT in 2019 gives conflicting weak to moderate correlation with a graduation rate of high school students with economically disadvantaged; increase in ACGR of economically disadvantaged students, increase in act19 participation but a decrease in sat19 participation.
#
# - Weak direct correlation (0.12) between poverty rate VS ACGR of economically disadvantaged students for years of 2018-2019.

# %% [markdown]
# ### What about those weak correlation observed above? Do they make sense?

# %% [markdown]
# A weak correlation (0.12) between the poverty rate VS ACGR of economically disadvantaged students for the year of 2018-2019 was observed earlier. This was not the expected correlation at first thought, expected a moderate correlation (inverse or direct) between these 2 variables since we are using the same financial metrics to measure them. However, after careful scrutinizing of the  [`ACGR(2018-2019).xls`] dataset, a remark was observed which states that students must meet the state criteria for classification as 'economically disadvantaged' students. There may be different criteria in each of the 51 states, resulting in the lack of standardization of criteria to be 'economically disadvantaged'. This may possibly explain the weak correlation observed earlier for poverty rate VS ACGR of economically disadvantaged students. An alternative explanation may simply be that high school students' graduation has little relationship with their economic background.

# %% [markdown]
# However, this does not mean [`ACGR(2018-2019).xls`] dataset is not useful in this study. We have seen a moderate direct correlation between ACGR of economically disadvantaged students VS ACGR of homeless students enrolled and students with disabilities, these are important factors to consider funding strategies for the different states.

# %% [markdown]
# ### Now back to funding strategies, since we have seen the correlation between poverty and normalized scores, which states require resource funding for improvement?

# %% [markdown]
# The following 4 datasets (created earlier) would give us a better idea on which states to provide funding resources to:
#
# - **Bottom 5 ranking states in terms of normalized SAT and ACT scores** --> These states perform the worst for both the ACT and SAT exams in 2019, resulting in the bottom 5 normalized scores
#
# - **Bottom 5 ranking states in terms of participation for national(SAT/ACT) exams** --> These states have the lowest participation rate for the national exam(SAT/ACT) in the year of 2019, less than 70% for both the ACT and SAT exams.
#
# - **Top 5 ranking states in terms of poverty** --> These states ranked the highest in poverty rate (%) for the year 2018-2019
#
# - **Bottom 5 ranking states in ACGR of economically disadvantaged students** --> These states ranked the lowest in adjusted cohort graduation (%) of high school students who are economically disadvantaged for the year 2018-2019

# %% [markdown]
# #### Bottom 5 ranking states in terms of combined SAT and ACT normalized  scores

# %%
df_bottom_states_19.head()
# Out:
#              state  act19_composite  sat19_total  normalized_sat_act_score
# 36        Oklahoma             18.9          963                  1.126875
# 40  South Carolina             18.8         1030                  1.165972
# 48   West Virginia             20.8          943                  1.167153
# 9          Florida             20.1          999                  1.182708
# 31      New Mexico             19.3         1073                  1.206736

# %% [markdown]
# #### Bottom 5 ranking states in terms of participation for national(SAT/ACT) exams

# %%
df_bottom_participation_19.head()
# Out:
#          state  act19_participation  sat19_participation  \
# 15        Iowa                 0.66                 0.03
# 1       Alaska                 0.38                 0.41
# 31  New Mexico                 0.63                 0.18
# 4   California                 0.23                 0.63
# 45     Vermont                 0.20                 0.66
#
#     total_participation_19
# 15                   0.345
# 1                    0.395
# 31                   0.405
# 4                    0.430
# 45                   0.430

# %% [markdown]
# #### Top 5 ranking states in terms of poverty (2018-2019)

# %%
df_highest_poverty = df_highest_poverty[['state','2_years_avg_proverty_rate']]
df_highest_poverty.head()
# Out:
#             state  2_years_avg_proverty_rate
# 24    Mississippi                       19.4
# 18      Louisiana                       18.4
# 31     New Mexico                       16.0
# 3        Arkansas                       15.0
# 48  West Virginia                       14.9

# %% [markdown]
# #### Bottom 5 ranking states in ACGR of economically disadvantaged students (2018-2019)

# %%
df_lowest_ed[['state','economically_disadvantaged']].head()
# Out:
#                    state  economically_disadvantaged
# 8   District of Columbia                        58.6
# 31            New Mexico                        70.0
# 22              Michigan                        70.8
# 5               Colorado                        70.9
# 35                  Ohio                        71.0

# %% [markdown]
# #### Finding meaningful interceptions between the 4 datasets above

# %% [markdown]
# #### Intercept of highest poverty states VS lowest graduation rate of economically disadvantaged students

# %%
df_lowest15_ed = df_lowest_ed.head(15)
df_highest15_poverty = df_highest_poverty.head(15)

# %%
intercept_econs1_df = pd.merge(df_lowest15_ed, df_highest15_poverty, how='inner', on=['state'])
intercept_econs1_df[['state','2_years_avg_proverty_rate_x','economically_disadvantaged']]
# Out:
#                   state  2_years_avg_proverty_rate_x  \
# 0  District of Columbia                         13.6
# 1            New Mexico                         16.0
# 2             Louisiana                         18.4
#
#    economically_disadvantaged
# 0                        58.6
# 1                        70.0
# 2                        74.4

# %% [markdown]
# #### Intercept of highest poverty states VS lowest combined SAT and ACT normalized exam scores

# %%
df_bottom10_states_19 = df_bottom_states_19.head(10)
df_highest10_poverty = df_highest_poverty.head(10)

# %%
intercept_econs2_df = pd.merge(df_bottom10_states_19, df_highest10_poverty, how='inner', on=['state'])
intercept_econs2_df
# Out:
#             state  act19_composite  sat19_total  normalized_sat_act_score  \
# 0  South Carolina             18.8         1030                  1.165972
# 1   West Virginia             20.8          943                  1.167153
# 2      New Mexico             19.3         1073                  1.206736
#
#    2_years_avg_proverty_rate
# 0                       13.9
# 1                       14.9
# 2                       16.0

# %% [markdown]
# #### Intercept of highest poverty states VS lowest participation for national exams

# %%
df_bottom15_participation_19 = df_bottom_participation_19.head(15)
df_highest15_poverty = df_highest_poverty.head(15)

# %%
intercept_econs3_df = pd.merge(df_bottom15_participation_19, df_highest15_poverty, how='inner', on=['state'])
intercept_econs3_df
# Out:
#         state  act19_participation  sat19_participation  \
# 0  New Mexico                 0.63                 0.18
# 1       Texas                 0.39                 0.68
#
#    total_participation_19  2_years_avg_proverty_rate
# 0                   0.405                       16.0
# 1                   0.535                       12.4

# %% [markdown]
# ### Other Visualization Charts

# %%
fig = px.scatter(economical_summary_df, x="economically_disadvantaged", y="2_years_avg_proverty_rate",color='state', title="Poverty Rate VS Graduation Rate of Economically Disadvantaged High School Students");
fig.show()

# %%
merged_all_df = economical_summary_df.merge(final_merged, how = 'left', on = ('state').lower())

# %%
fig = px.scatter(merged_all_df, x="normalized_sat_act_score", y="2_years_avg_proverty_rate",color='state', title="Poverty Rate VS Normalized Exam Scores");
fig.show()

# %%
merged_all_df[['2_years_avg_proverty_rate','economically_disadvantaged','normalized_sat_act_score']].describe()
# Out:
#        2_years_avg_proverty_rate  economically_disadvantaged  \
# count                  51.000000                   51.000000
# mean                   10.841176                   78.282353
# std                     2.930541                    5.438813
# min                     4.900000                   58.600000
# 25%                     8.950000                   74.850000
# 50%                    10.300000                   78.500000
# 75%                    12.450000                   81.900000
# max                    19.400000                   87.800000
#
#        normalized_sat_act_score
# count                 51.000000
# mean                   1.291916
# std                    0.065271
# min                    1.126875
# 25%                    1.244792
# 50%                    1.300000
# 75%                    1.344306
# max                    1.408333

# %% [markdown]
# #### Observations from the datasets and charts:
#
# - Mississippi ranked highest in poverty but students generally do okay in the national exam (1.28 compared to normalized national exam score mean of 1.29) and observed to have a higher ACGR (82.2% compared to mean 78.3%) of economically disadvantaged students
#
# - Louisiana has the 2nd highest in poverty but students generally do okay in the national exam (within 1 STD away from the mean of 1.29) but are observed to have a low ACGR (est 25% quartile: 74.4%) of economically disadvantaged students
#
# - New Mexico is of primary concern, as it is the common intercept between the 4 datasets analyzed above, and it is ranked 3rd highest in poverty in the US with 16% of the people living in poverty. Additionally, both the normalized national exam score (est 1.20) and ACGR of economically disadvantaged students (est 70%) are below the 25% quartile (74.8%).
#
# - Both West Virginia and South Carolina have 14.9% and 13.9% population living in poverty respectively (2 STD worst off from mean), both these states have normalized national exam score (West Virginia: est 1.17, South Carolina: est 1.165) below the 25% quartile (est 1.24).
#
# - District of Columbia has the lowest ACGR of economically disadvantaged students at 58.6%, with a poverty rate at 13.6% (est 2 STD worst off from mean) and a normalized national exam score of  1.26 which is below 50% quartile. Additionally, the District of Columbia has consistently ranked the bottom 3 states from 2017 to 2019 for SAT exam scores.
#
# - Oklahoma has the lowest normalized test score at 1.12 but stays within 1 STD away from poverty mean and ACGR economically disadvantaged mean.

# %% [markdown]
# #### Investigating Okahoma Exam Score Trends

# %% [markdown]
# #### Year 2019

# %%
Okahoma_df_19 = merged_all_df[['state','act19_participation','sat19_participation','sat19_total','act19_composite','normalized_sat_act_score']]
Okahoma_df_19= Okahoma_df_19[Okahoma_df_19['state']=='Oklahoma']
Okahoma_df_19
# Out:
#        state  act19_participation  sat19_participation  sat19_total  \
# 36  Oklahoma                  1.0                 0.22          963
#
#     act19_composite  normalized_sat_act_score
# 36             18.9                  1.126875

# %% [markdown]
# #### Year 2018

# %%
Okahoma_df_18 = merged_all_df[['state','act18_participation','sat18_participation','sat18_total','act18_composite']]
Okahoma_df_18= Okahoma_df_18[Okahoma_df_18['state']=='Oklahoma']
Okahoma_df_18
# Out:
#        state  act18_participation  sat18_participation  sat18_total  \
# 36  Oklahoma                  1.0                 0.08         1062
#
#     act18_composite
# 36             19.3

# %% [markdown]
# #### Year 2017

# %%
Okahoma_df_17 = merged_all_df[['state','act17_participation','sat17_participation','sat17_total','act17_composite']]
Okahoma_df_17= Okahoma_df_17[Okahoma_df_17['state']=='Oklahoma']
Okahoma_df_17
# Out:
#        state  act17_participation  sat17_participation  sat17_total  \
# 36  Oklahoma                  1.0                 0.07         1047
#
#     act17_composite
# 36             19.4

# %% [markdown]
# #### Observation:
# For some reason, both sat and act scores worsen in 2019 for the state of Oklahoma, a 6% slide from 2018 level and 5.6% slide from 2017 calculated normalized scores. However, the year 2019 could just be an outlier for normalized score performance, and further analysis of future data might be needed for a conclusion.

# %% [markdown]
# ### We will now study which subject students tend to do worst for the national exam (SAT/ACT). This study will only apply to selected states (New Mexico, West Virginia, South Carolina, District of Columbia) that require resource fundings.

# %%
df_fund_sat = merged_all_df[['state','sat19_ebrw', 'sat19_math']]

#can only use 2017 dataset since 2019 dataset lack the mean subject scores for each state
df_fund_act = merged_all_df[['act17_english', 'act17_math', 'act17_reading','act17_science']]

# %%
# Set up the matplotlib figure
f, axes = plt.subplots(ncols=2, figsize=(16, 9))

ax=axes[0]
ax.set_title('SAT Average Subject Score (2019)')
df_fund_sat.boxplot(['sat19_ebrw', 'sat19_math'], ax=ax)
ax.set_ylabel('SAT Score');

ax=axes[1]
ax.set_title('SAT Average Subject Score (2017)')
df_fund_act.boxplot(['act17_english', 'act17_math', 'act17_reading','act17_science'], ax=ax)
ax.set_ylabel('ACT Score');

# %% [markdown]
# #### Observation:
# - Students tend to do worst in math for both ACT and SAT exams relative to other subjects.
#
# - Aside from math, students who took ACT eaxm did worst for english subjects.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# #### SUMMARY OF TRENDS OBSERVED:
#
# - Strong inverse correlation (-0.86) between ACT composite score and ACT participation rate; higher ACT participation rate tends is related to lower ACT composite score.
#
# - Similar inverse correlation (-0.87) is observed between SAT total score and SAT participation rate; higher SAT participation rate is related to lower SAT total score
#
# A possible explanation for observed trends: These inverse correlations between participation rate and exam scores are expected as statewide adoption of SAT/ACT exam means greater participation of students of different social-economic status, cohort differences, and academic achievements ([*source2*](https://www.act.org/content/dam/act/unsecured/documents/Statewide-Adoption.pdf)). College students who are not motivated to go to college will have to equally take the national exams.
#  As a result, an increasing percentage of low/mid-tier students lower the overall state average with statewide adoption of ACT/SAT ([*source3*](https://medium.com/@james.dargan/participation-skews-state-averages-f68969371a01)). Conversely, lower participation rate tend to have high exam score as self-selected elite students choose to pursue admission to elite universities voluntarily.
#
# - Strong inverse correlation between ACT participation rate and SAT participation rate which is logically sound as college pre-requisite only require students to take either ACT or SAT exam and not both.
#
# - SAT Participation rates have shown min, median, and interquartile (25%,75%) rates are increasing year over year. This seems logical as more and more states make it mandatory for high school students to sit for the SAT exam during recent years ([*source4*](https://blog.prepscholar.com/which-states-require-the-sat)). Conversely, ACT participation rates have shown min, median, and interquartile (25%) rates are consistently decreasing year over year. Logically it is understandable for ACT participation in the state to decrease if most of the high school students are taking SAT exams instead.
#
# - Moderate inverse correlation (-0.53) between 2019 normalized exam scores and poverty rate; lower normalized exam scores tend to mean higher poverty rate at that given state. Poverty is defined as not having enough income to meet basic needs, such as housing, food, clothing, and healthcare. Logically, it makes sense for a state with a large percentile of population in poverty to perform worst in national exams as parents spent less on enrichment classes for their children. Additionally, parents lack the adequate skill to guide their children in proper career plannings which results in a vicious cycle when these children start a family of their own. The lack of proper teaching materials, lack of a standardized test system for international use creates a gap between learning achievement and what is required by society ([*source5*](https://www.grin.com/document/384366)).
#
# - Moderate direct correlation (0.36) is observed between the graduation rate of economically disadvantaged high school students VS graduation rate of homeless students enrolled.
#
# - Moderate direct correlation (0.55) is observed between the graduation rate of economically disadvantaged high school students VS graduation rate of students with disabilities for the year 2018-2019.
#
# We have seen a moderate direct correlation (Point 6) between ACGR of economically disadvantaged students VS ACGR of homeless students enrolled and students with disabilities (Point 7), these are important factors to consider funding strategies for the different states.
#
# - Comparing the subject test scores for both SAT and ACT exams, it is observed that students tend to do worst in math for both ACT and SAT exams relative to other subjects. Aside from math, students who took the ACT exam did worst for English subjects.

# %% [markdown]
# #### FUNDING RECOMMENDATIONS:
#
# With these correlations observed, we have identified 4 socioeconomic poorer states that could benefit from financial/ resource funding from the US Department of Education to improve their participation and scoring of national exams.
#
# - New Mexico ranked 3rd highest in poverty in the US with 16% (2019) of the people living in poverty. Additionally, both the normalized test result (est 1.20) and ACGR of economically disadvantaged students (est 70%) are below the 25% quartile (74.8%). Unfortunately, New Mexico's public schools are ranked the worst in the U.S., with the highest dropout rates of any state. Although the dropout rate has improved over the years, it still lags behind the overall US rate by more than 5 percentage points (according to 2021 data) ([*source6*](https://stacker.com/stories/1925/states-where-high-schoolers-are-least-likely-graduate)).
#
# - West Virginia is the top 5 poorest U.S. states, with a poverty rate of 14.9%. (2 STD worst off from mean poverty rate), and have a normalized national exam score (1.17) below the 25% quartile (est 1.24). Additionally, West Virginia's educational attainment levels are on the low side, with the lowest percentage of adults with a Bachelor's degree or higher (according to 2021 data) ([*source7*](https://worldpopulationreview.com/state-rankings/least-educated-states)).
#
# - District of Columbia has the lowest ACGR of economically disadvantaged students at 58.6%, with a poverty rate at 13.6% (est 2 STD worst off from mean) and a normalized test score of  1.26 which is below the 50% quartile. Additionally, the District of Columbia has consistently ranked the bottom 3 states from 2017 to 2019 for SAT exam scores.
#
# - South Carolina has 13.9% of the population living in poverty (2 STD worst off from mean), and a normalized national exam score of 1.165, which is below the 25% quartile (est 1.24). According to an online survey, South Carolina has 1 of the lowest % of millennials in the state, which is not surprising given that it also has the lowest average earning for Millenials. South Carolina also ranks top 5 for having the highest unemployment rate ([*source8*](https://wallethub.com/edu/best-states-for-millennials/33371)).
#
# Our recommended approach for these states would be in the form of financial aids to high school students and social engagements to reduce dropout rates. Crucial to provide these students proper guidance for college and career planning and promote self-development along the process. Fundings can also be used to attract better teachers with higher salaries and more funding towards better teaching materials to help better prepare students for the exam, particularly in Math subject for SAT exam, Math and English for the ACT exam. We have also seen that the District of Columbia and New Mexico are states with the highest poverty rate and lowest graduation rate of economically disadvantaged high school students, these states might require more priority in fundings to help financially needy students.
#
# Additionally, these states should offer free SAT/ACT exams to all high schoolers on their 1st attempt and financial grants for students who choose to take these national exams the 2nd time. As a result, some of the added benefits for offering free national exams ([*source4*](https://blog.collegevine.com/states-that-require-sat/)):
#
# - Streamlining national exams <br/>
# - Increasing access to national exams, particularly for lower-income students <br/>
# - Inspiring some students to apply to college <br/>
#
# #### Additional recommendation for low participation rate for national exam
#
# Provide free ACT/SAT tests for high school students to the bottom 3 lowest total participation states to encourage students to sit for national exams. The 3 states are:
#
# - Lowa
# - Alaska
# - New Mexico (Already covered above)

# %% [markdown]
# #### Recommended  Additional Dataset For Targeted Funding
#
# - ACT 2019 Dataset with subject composite scores for better targeted funding.
# - Datasets on average teacher-to-students ratio for each state and how it impacts national exam score

# %% [markdown]
# ### CITATIONS AND SOURCES
# The sources of the datasets used in this analysis:
# - Source0: https://education.seattlepi.com/factors-influencing-sat-scores-2589.html
# - source1: https://blog.collegevine.com/states-that-require-sat
# - source2: https://www.act.org/content/dam/act/unsecured/documents/Statewide-Adoption.pdf
# - source3: https://medium.com/@james.dargan/participation-skews-state-averages-f68969371a01
# - source4: https://blog.collegevine.com/states-that-require-sat/
# - source5: https://www.grin.com/document/384366
# - source6: https://stacker.com/stories/1925/states-where-high-schoolers-are-least-likely-graduate
# - source7: https://worldpopulationreview.com/state-rankings/least-educated-states
# - source8: https://wallethub.com/edu/best-states-for-millennials/33371
# - source9: https://github.com/cs109/2015/blob/master/Lectures/01-Introduction.pdf
# - dataset1: https://www.census.gov/data/tables/2020/demo/income-poverty/p60-270.html
# - dataset2: https://nces.ed.gov/programs/digest/d18/tables/dt18_219.46.asp
